# %%
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import seaborn as sns
import os
from tqdm import tqdm
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D
from keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, roc_auc_score, roc_curve, auc

# %%
# Google colab connection
from google.colab import drive
drive.mount('/content/drive')
# !unzip "/content/drive/MyDrive/RSBDSL38_train_val_test.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train_val_data/27/class-27-102.jpg
#   inflating: train_val_data/27/class-27-103.jpg
#   inflating: train_val_data/27/class-27-105.jpg
#   inflating: train_val_data/27/class-27-106.jpg
#   inflating: train_val_data/27/class-27-107.jpg
#   inflating: train_val_data/27/class-27-108.jpg
#   inflating: train_val_data/27/class-27-11.jpg
#   inflating: train_val_data/27/class-27-110.jpg
#   inflating: train_val_data/27/class-27-111.jpg
#   inflating: train_val_data/27/class-27-112.jpg
#   inflating: train_val_data/27/class-27-113.jpg
#   inflating: train_val_data/27/class-27-114.jpg
#   inflating: train_val_data/27/class-27-115.jpg
#   inflating: train_val_data/27/class-27-116.jpg
#   inflating: train_val_data/27/class-27-118.jpg
#   inflating: train_val_data/27/class-27-12.jpg
#   inflating: train_val_data/27/class-27-120.jpg
#   inflating: train_val_data/27/class-27-121.jpg
#   inflating: train_val_data/27/class-27-122.jpg
#   inflating: train_val_data/27/class-27-123.jpg
#   inflating: train_val_data/27/class-27-124.jpg
#   inflating: train_val_data/27/class-27-125.jpg
#   inflating: train_val_data/27/class-27-126.jpg
#   inflating: train_val_data/27/class-27-127.jpg
#   inflating: train_val_data/27/class-27-129.jpg
#   inflating: train_val_data/27/class-27-13.jpg
#   inflating: train_val_data/27/class-27-130.jpg
#   inflating: train_val_data/27/class-27-131.jpg
#   inflating: train_val_data/27/class-27-133.jpg
#   inflating: train_val_data/27/class-27-134.jpg
#   inflating: train_val_data/27/class-27-135.jpg
#   inflating: train_val_data/27/class-27-138.jpg
#   inflating: train_val_data/27/class-27-139.jpg
#   inflating: train_val_data/27/class-27-14.jpg
#   inflating: train_val_data/27/class-27-140.jpg
#   inflating: train_val_data/27/class-27-141.jpg
#   inflating: train_val_data/27/class-27-142.jpg
#   inflating: train_val_data/27/class-27-143.jpg
#   inflating: train_val_data/27/class-27-144.jpg
#   inflating: train_val_data/27/class-27-146.jpg
#   inflating: train_val_data/27/class-27-147.jpg
#   inflating: train_val_data/27/class-27-148.jpg
#   inflating: train_val_data/27/class-27-149.jpg
#   inflating: train_val_data/27/class-27-15.jpg
#   inflating: train_val_data/27/class-27-150.jpg
#   inflating: train_val_data/27/class-27-152.jpg
#   inflating: train_val_data/27/class-27-153.jpg
#   inflating: train_val_data/27/class-27-155.jpg
#   inflating: train_val_data/27/class-27-156.jpg
#   inflating: train_val_data/27/class-27-157.jpg
#   inflating: train_val_data/27/class-27-158.jpg
#   inflating: train_val_data/27/class-27-159.jpg
#   inflating: train_val_data/27/class-27-16.jpg
#   inflating: train_val_data/27/class-27-160.jpg
#   inflating: train_val_data/27/class-27-161.jpg
#   inflating: train_val_data/27/class-27-162.jpg
#   inflating: train_val_data/27/class-27-163.jpg
#   inflating: train_val_data/27/class-27-164.jpg
#   inflating: train_val_data/27/class-27-165.jpg
#   inflating: train_val_data/27/class-27-166.jpg
#   inflating: train_val_data/27/class-27-167.jpg
#   inflating: train_val_data/27/class-27-168.jpg
#   inflating: train_val_data/27/class-27-169.jpg
#   inflating: train_val_data/27/class-27-170.jpg
#   inflating: train_val_data/27/class-27-171.jpg
#   inflating: train_val_data/27/class-27-172.jpg
#   inflating: train_val_data/27/class-27-173.jpg
#   inflating: train_val_data/27/class-27-175.jpg
#   inflating: train_val_data/27/class-27-176.jpg
#   inflating: train_val_data/27/class-27-177.jpg
#   inflating: train_val_data/27/class-27-178.jpg
#   inflating: train_val_data/27/class-27-179.jpg
#   inflating: train_val_data/27/class-27-18.jpg
#   inflating: train_val_data/27/class-27-180.jpg
#   inflating: train_val_data/27/class-27-182.jpg
#   inflating: train_val_data/27/class-27-183.jpg
#   inflating: train_val_data/27/class-27-184.jpg
#   inflating: train_val_data/27/class-27-185.jpg
#   inflating: train_val_data/27/class-27-186.jpg
#   inflating: train_val_data/27/class-27-187.jpg
#   inflating: train_val_data/27/class-27-188.jpg
#   inflating: train_val_data/27/class-27-19.jpg
#   inflating: train_val_data/27/class-27-190.jpg
#   inflating: train_val_data/27/class-27-191.jpg
#   inflating: train_val_data/27/class-27-192.jpg
#   inflating: train_val_data/27/class-27-193.jpg
#   inflating: train_val_data/27/class-27-194.jpg
#   inflating: train_val_data/27/class-27-195.jpg
#   inflating: train_val_data/27/class-27-196.jpg
#   inflating: train_val_data/27/class-27-197.jpg
#   inflating: train_val_data/27/class-27-198.jpg
#   inflating: train_val_data/27/class-27-199.jpg
#   inflating: train_val_data/27/class-27-20.jpg
#   inflating: train_val_data/27/class-27-200.jpg
#   inflating: train_val_data/27/class-27-201.jpg
#   inflating: train_val_data/27/class-27-202.jpg
#   inflating: train_val_data/27/class-27-203.jpg
#   inflating: train_val_data/27/class-27-204.jpg
#   inflating: train_val_data/27/class-27-205.jpg
#   inflating: train_val_data/27/class-27-206.jpg
#   inflating: train_val_data/27/class-27-207.jpg
#   inflating: train_val_data/27/class-27-208.jpg
#   inflating: train_val_data/27/class-27-209.jpg
#   inflating: train_val_data/27/class-27-21.jpg
#   inflating: train_val_data/27/class-27-210.jpg
#   inflating: train_val_data/27/class-27-211.jpg
#   inflating: train_val_data/27/class-27-213.jpg
#   inflating: train_val_data/27/class-27-214.jpg
#   inflating: train_val_data/27/class-27-215.jpg
#   inflating: train_val_data/27/class-27-216.jpg
#   inflating: train_val_data/27/class-27-217.jpg
#   inflating: train_val_data/27/class-27-218.jpg
#   inflating: train_val_data/27/class-27-219.jpg
#   inflating: train_val_data/27/class-27-22.jpg
#   inflating: train_val_data/27/class-27-220.jpg
#   inflating: train_val_data/27/class-27-221.jpg
#   inflating: train_val_data/27/class-27-222.jpg
#   inflating: train_val_data/27/class-27-223.jpg
#   inflating: train_val_data/27/class-27-224.jpg
#   inflating: train_val_data/27/class-27-225.jpg
#   inflating: train_val_data/27/class-27-227.jpg
#   inflating: train_val_data/27/class-27-228.jpg
#   inflating: train_val_data/27/class-27-229.jpg
#   inflating: train_val_data/27/class-27-23.jpg
#   inflating: train_val_data/27/class-27-230.jpg
#   inflating: train_val_data/27/class-27-231.jpg
#   inflating: train_val_data/27/class-27-232.jpg
#   inflating: train_val_data/27/class-27-234.jpg
#   inflating: train_val_data/27/class-27-235.jpg
#   inflating: train_val_data/27/class-27-236.jpg
#   inflating: train_val_data/27/class-27-237.jpg
#   inflating: train_val_data/27/class-27-238.jpg
#   inflating: train_val_data/27/class-27-239.jpg
#   inflating: train_val_data/27/class-27-24.jpg
#   inflating: train_val_data/27/class-27-240.jpg
#   inflating: train_val_data/27/class-27-241.jpg
#   inflating: train_val_data/27/class-27-242.jpg
#   inflating: train_val_data/27/class-27-243.jpg
#   inflating: train_val_data/27/class-27-244.jpg
#   inflating: train_val_data/27/class-27-245.jpg
#   inflating: train_val_data/27/class-27-246.jpg
#   inflating: train_val_data/27/class-27-247.jpg
#   inflating: train_val_data/27/class-27-248.jpg
#   inflating: train_val_data/27/class-27-249.jpg
#   inflating: train_val_data/27/class-27-25.jpg
#   inflating: train_val_data/27/class-27-250.jpg
#   inflating: train_val_data/27/class-27-251.jpg
#   inflating: train_val_data/27/class-27-252.jpg
#   inflating: train_val_data/27/class-27-253.jpg
#   inflating: train_val_data/27/class-27-254.jpg
#   inflating: train_val_data/27/class-27-255.jpg
#   inflating: train_val_data/27/class-27-257.jpg
#   inflating: train_val_data/27/class-27-258.jpg
#   inflating: train_val_data/27/class-27-259.jpg
#   inflating: train_val_data/27/class-27-26.jpg
#   inflating: train_val_data/27/class-27-260.jpg
#   inflating: train_val_data/27/class-27-261.jpg
#   inflating: train_val_data/27/class-27-262.jpg
#   inflating: train_val_data/27/class-27-263.jpg
#   inflating: train_val_data/27/class-27-265.jpg
#   inflating: train_val_data/27/class-27-266.jpg
#   inflating: train_val_data/27/class-27-267.jpg
#   inflating: train_val_data/27/class-27-268.jpg
#   inflating: train_val_data/27/class-27-269.jpg
#   inflating: train_val_data/27/class-27-27.jpg
#   inflating: train_val_data/27/class-27-271.jpg
#   inflating: train_val_data/27/class-27-272.jpg
#   inflating: train_val_data/27/class-27-273.jpg
#   inflating: train_val_data/27/class-27-276.jpg
#   inflating: train_val_data/27/class-27-277.jpg
#   inflating: train_val_data/27/class-27-278.jpg
#   inflating: train_val_data/27/class-27-279.jpg
#   inflating: train_val_data/27/class-27-28.jpg
#   inflating: train_val_data/27/class-27-280.jpg
#   inflating: train_val_data/27/class-27-282.jpg
#   inflating: train_val_data/27/class-27-283.jpg
#   inflating: train_val_data/27/class-27-284.jpg
#   inflating: train_val_data/27/class-27-285.jpg
#   inflating: train_val_data/27/class-27-286.jpg
#   inflating: train_val_data/27/class-27-287.jpg
#   inflating: train_val_data/27/class-27-288.jpg
#   inflating: train_val_data/27/class-27-289.jpg
#   inflating: train_val_data/27/class-27-29.jpg
#   inflating: train_val_data/27/class-27-290.jpg
#   inflating: train_val_data/27/class-27-291.jpg
#   inflating: train_val_data/27/class-27-292.jpg
#   inflating: train_val_data/27/class-27-293.jpg
#   inflating: train_val_data/27/class-27-295.jpg
#   inflating: train_val_data/27/class-27-296.jpg
#   inflating: train_val_data/27/class-27-297.jpg
#   inflating: train_val_data/27/class-27-298.jpg
#   inflating: train_val_data/27/class-27-299.jpg
#   inflating: train_val_data/27/class-27-3.jpg
#   inflating: train_val_data/27/class-27-30.jpg
#   inflating: train_val_data/27/class-27-300.jpg
#   inflating: train_val_data/27/class-27-301.jpg
#   inflating: train_val_data/27/class-27-302.jpg
#   inflating: train_val_data/27/class-27-303.jpg
#   inflating: train_val_data/27/class-27-304.jpg
#   inflating: train_val_data/27/class-27-305.jpg
#   inflating: train_val_data/27/class-27-306.jpg
#   inflating: train_val_data/27/class-27-32.jpg
#   inflating: train_val_data/27/class-27-33.jpg
#   inflating: train_val_data/27/class-27-34.jpg
#   inflating: train_val_data/27/class-27-35.jpg
#   inflating: train_val_data/27/class-27-36.jpg
#   inflating: train_val_data/27/class-27-37.jpg
#   inflating: train_val_data/27/class-27-38.jpg
#   inflating: train_val_data/27/class-27-39.jpg
#   inflating: train_val_data/27/class-27-4.jpg
#   inflating: train_val_data/27/class-27-40.jpg
#   inflating: train_val_data/27/class-27-41.jpg
#   inflating: train_val_data/27/class-27-42.jpg
#   inflating: train_val_data/27/class-27-44.jpg
#   inflating: train_val_data/27/class-27-45.jpg
#   inflating: train_val_data/27/class-27-46.jpg
#   inflating: train_val_data/27/class-27-47.jpg
#   inflating: train_val_data/27/class-27-48.jpg
#   inflating: train_val_data/27/class-27-49.jpg
#   inflating: train_val_data/27/class-27-5.jpg
#   inflating: train_val_data/27/class-27-50.jpg
#   inflating: train_val_data/27/class-27-51.jpg
#   inflating: train_val_data/27/class-27-52.jpg
#   inflating: train_val_data/27/class-27-53.jpg
#   inflating: train_val_data/27/class-27-54.jpg
#   inflating: train_val_data/27/class-27-55.jpg
#   inflating: train_val_data/27/class-27-56.jpg
#   inflating: train_val_data/27/class-27-57.jpg
#   inflating: train_val_data/27/class-27-58.jpg
#   inflating: train_val_data/27/class-27-59.jpg
#   inflating: train_val_data/27/class-27-6.jpg
#   inflating: train_val_data/27/class-27-60.jpg
#   inflating: train_val_data/27/class-27-61.jpg
#   inflating: train_val_data/27/class-27-62.jpg
#   inflating: train_val_data/27/class-27-63.jpg
#   inflating: train_val_data/27/class-27-64.jpg
#   inflating: train_val_data/27/class-27-66.jpg
#   inflating: train_val_data/27/class-27-67.jpg
#   inflating: train_val_data/27/class-27-68.jpg
#   inflating: train_val_data/27/class-27-69.jpg
#   inflating: train_val_data/27/class-27-7.jpg
#   inflating: train_val_data/27/class-27-70.jpg
#   inflating: train_val_data/27/class-27-71.jpg
#   inflating: train_val_data/27/class-27-72.jpg
#   inflating: train_val_data/27/class-27-73.jpg
#   inflating: train_val_data/27/class-27-74.jpg
#   inflating: train_val_data/27/class-27-75.jpg
#   inflating: train_val_data/27/class-27-76.jpg
#   inflating: train_val_data/27/class-27-77.jpg
#   inflating: train_val_data/27/class-27-78.jpg
#   inflating: train_val_data/27/class-27-8.jpg
#   inflating: train_val_data/27/class-27-80.jpg
#   inflating: train_val_data/27/class-27-81.jpg
#   inflating: train_val_data/27/class-27-82.jpg
#   inflating: train_val_data/27/class-27-83.jpg
#   inflating: train_val_data/27/class-27-84.jpg
#   inflating: train_val_data/27/class-27-85.jpg
#   inflating: train_val_data/27/class-27-86.jpg
#   inflating: train_val_data/27/class-27-87.jpg
#   inflating: train_val_data/27/class-27-88.jpg
#   inflating: train_val_data/27/class-27-89.jpg
#   inflating: train_val_data/27/class-27-9.jpg
#   inflating: train_val_data/27/class-27-90.jpg
#   inflating: train_val_data/27/class-27-91.jpg
#   inflating: train_val_data/27/class-27-92.jpg
#   inflating: train_val_data/27/class-27-94.jpg
#   inflating: train_val_data/27/class-27-95.jpg
#   inflating: train_val_data/27/class-27-96.jpg
#   inflating: train_val_data/27/class-27-97.jpg
#   inflating: train_val_data/27/class-27-98.jpg
#   inflating: train_val_data/27/class-27-99.jpg
#    creating: train_val_data/28/
#   inflating: train_val_data/28/class-28-1.jpg
#   inflating: train_val_data/28/class-28-10.jpg
#   inflating: train_val_data/28/class-28-100.jpg
#   inflating: train_val_data/28/class-28-101.jpg
#   inflating: train_val_data/28/class-28-102.jpg
#   inflating: train_val_data/28/class-28-103.jpg
#   inflating: train_val_data/28/class-28-104.jpg
#   inflating: train_val_data/28/class-28-105.jpg
#   inflating: train_val_data/28/class-28-107.jpg
#   inflating: train_val_data/28/class-28-108.jpg
#   inflating: train_val_data/28/class-28-109.jpg
#   inflating: train_val_data/28/class-28-110.jpg
#   inflating: train_val_data/28/class-28-111.jpg
#   inflating: train_val_data/28/class-28-112.jpg
#   inflating: train_val_data/28/class-28-113.jpg
#   inflating: train_val_data/28/class-28-114.jpg
#   inflating: train_val_data/28/class-28-115.jpg
#   inflating: train_val_data/28/class-28-116.jpg
#   inflating: train_val_data/28/class-28-117.jpg
#   inflating: train_val_data/28/class-28-118.jpg
#   inflating: train_val_data/28/class-28-119.jpg
#   inflating: train_val_data/28/class-28-12.jpg
#   inflating: train_val_data/28/class-28-122.jpg
#   inflating: train_val_data/28/class-28-123.jpg
#   inflating: train_val_data/28/class-28-124.jpg
#   inflating: train_val_data/28/class-28-125.jpg
#   inflating: train_val_data/28/class-28-126.jpg
#   inflating: train_val_data/28/class-28-127.jpg
#   inflating: train_val_data/28/class-28-128.jpg
#   inflating: train_val_data/28/class-28-131.jpg
#   inflating: train_val_data/28/class-28-132.jpg
#   inflating: train_val_data/28/class-28-133.jpg
#   inflating: train_val_data/28/class-28-134.jpg
#   inflating: train_val_data/28/class-28-135.jpg
#   inflating: train_val_data/28/class-28-136.jpg
#   inflating: train_val_data/28/class-28-137.jpg
#   inflating: train_val_data/28/class-28-138.jpg
#   inflating: train_val_data/28/class-28-139.jpg
#   inflating: train_val_data/28/class-28-140.jpg
#   inflating: train_val_data/28/class-28-141.jpg
#   inflating: train_val_data/28/class-28-142.jpg
#   inflating: train_val_data/28/class-28-143.jpg
#   inflating: train_val_data/28/class-28-144.jpg
#   inflating: train_val_data/28/class-28-145.jpg
#   inflating: train_val_data/28/class-28-147.jpg
#   inflating: train_val_data/28/class-28-148.jpg
#   inflating: train_val_data/28/class-28-15.jpg
#   inflating: train_val_data/28/class-28-150.jpg
#   inflating: train_val_data/28/class-28-151.jpg
#   inflating: train_val_data/28/class-28-152.jpg
#   inflating: train_val_data/28/class-28-153.jpg
#   inflating: train_val_data/28/class-28-154.jpg
#   inflating: train_val_data/28/class-28-155.jpg
#   inflating: train_val_data/28/class-28-156.jpg
#   inflating: train_val_data/28/class-28-157.jpg
#   inflating: train_val_data/28/class-28-158.jpg
#   inflating: train_val_data/28/class-28-159.jpg
#   inflating: train_val_data/28/class-28-16.jpg
#   inflating: train_val_data/28/class-28-160.jpg
#   inflating: train_val_data/28/class-28-161.jpg
#   inflating: train_val_data/28/class-28-162.jpg
#   inflating: train_val_data/28/class-28-163.jpg
#   inflating: train_val_data/28/class-28-164.jpg
#   inflating: train_val_data/28/class-28-165.jpg
#   inflating: train_val_data/28/class-28-166.jpg
#   inflating: train_val_data/28/class-28-168.jpg
#   inflating: train_val_data/28/class-28-169.jpg
#   inflating: train_val_data/28/class-28-17.jpg
#   inflating: train_val_data/28/class-28-170.jpg
#   inflating: train_val_data/28/class-28-171.jpg
#   inflating: train_val_data/28/class-28-172.jpg
#   inflating: train_val_data/28/class-28-173.jpg
#   inflating: train_val_data/28/class-28-174.jpg
#   inflating: train_val_data/28/class-28-175.jpg
#   inflating: train_val_data/28/class-28-176.jpg
#   inflating: train_val_data/28/class-28-177.jpg
#   inflating: train_val_data/28/class-28-178.jpg
#   inflating: train_val_data/28/class-28-18.jpg
#   inflating: train_val_data/28/class-28-180.jpg
#   inflating: train_val_data/28/class-28-181.jpg
#   inflating: train_val_data/28/class-28-182.jpg
#   inflating: train_val_data/28/class-28-183.jpg
#   inflating: train_val_data/28/class-28-184.jpg
#   inflating: train_val_data/28/class-28-185.jpg
#   inflating: train_val_data/28/class-28-186.jpg
#   inflating: train_val_data/28/class-28-187.jpg
#   inflating: train_val_data/28/class-28-189.jpg
#   inflating: train_val_data/28/class-28-19.jpg
#   inflating: train_val_data/28/class-28-190.jpg
#   inflating: train_val_data/28/class-28-191.jpg
#   inflating: train_val_data/28/class-28-192.jpg
#   inflating: train_val_data/28/class-28-193.jpg
#   inflating: train_val_data/28/class-28-194.jpg
#   inflating: train_val_data/28/class-28-195.jpg
#   inflating: train_val_data/28/class-28-196.jpg
#   inflating: train_val_data/28/class-28-197.jpg
#   inflating: train_val_data/28/class-28-198.jpg
#   inflating: train_val_data/28/class-28-199.jpg
#   inflating: train_val_data/28/class-28-20.jpg
#   inflating: train_val_data/28/class-28-200.jpg
#   inflating: train_val_data/28/class-28-201.jpg
#   inflating: train_val_data/28/class-28-202.jpg
#   inflating: train_val_data/28/class-28-203.jpg
#   inflating: train_val_data/28/class-28-204.jpg
#   inflating: train_val_data/28/class-28-205.jpg
#   inflating: train_val_data/28/class-28-206.jpg
#   inflating: train_val_data/28/class-28-207.jpg
#   inflating: train_val_data/28/class-28-208.jpg
#   inflating: train_val_data/28/class-28-209.jpg
#   inflating: train_val_data/28/class-28-21.jpg
#   inflating: train_val_data/28/class-28-210.jpg
#   inflating: train_val_data/28/class-28-213.jpg
#   inflating: train_val_data/28/class-28-214.jpg
#   inflating: train_val_data/28/class-28-215.jpg
#   inflating: train_val_data/28/class-28-216.jpg
#   inflating: train_val_data/28/class-28-217.jpg
#   inflating: train_val_data/28/class-28-218.jpg
#   inflating: train_val_data/28/class-28-219.jpg
#   inflating: train_val_data/28/class-28-22.jpg
#   inflating: train_val_data/28/class-28-220.jpg
#   inflating: train_val_data/28/class-28-221.jpg
#   inflating: train_val_data/28/class-28-223.jpg
#   inflating: train_val_data/28/class-28-224.jpg
#   inflating: train_val_data/28/class-28-225.jpg
#   inflating: train_val_data/28/class-28-227.jpg
#   inflating: train_val_data/28/class-28-228.jpg
#   inflating: train_val_data/28/class-28-229.jpg
#   inflating: train_val_data/28/class-28-23.jpg
#   inflating: train_val_data/28/class-28-230.jpg
#   inflating: train_val_data/28/class-28-231.jpg
#   inflating: train_val_data/28/class-28-232.jpg
#   inflating: train_val_data/28/class-28-233.jpg
#   inflating: train_val_data/28/class-28-234.jpg
#   inflating: train_val_data/28/class-28-235.jpg
#   inflating: train_val_data/28/class-28-236.jpg
#   inflating: train_val_data/28/class-28-237.jpg
#   inflating: train_val_data/28/class-28-238.jpg
#   inflating: train_val_data/28/class-28-239.jpg
#   inflating: train_val_data/28/class-28-24.jpg
#   inflating: train_val_data/28/class-28-240.jpg
#   inflating: train_val_data/28/class-28-241.jpg
#   inflating: train_val_data/28/class-28-242.jpg
#   inflating: train_val_data/28/class-28-243.jpg
#   inflating: train_val_data/28/class-28-244.jpg
#   inflating: train_val_data/28/class-28-245.jpg
#   inflating: train_val_data/28/class-28-246.jpg
#   inflating: train_val_data/28/class-28-247.jpg
#   inflating: train_val_data/28/class-28-248.jpg
#   inflating: train_val_data/28/class-28-25.jpg
#   inflating: train_val_data/28/class-28-250.jpg
#   inflating: train_val_data/28/class-28-251.jpg
#   inflating: train_val_data/28/class-28-252.jpg
#   inflating: train_val_data/28/class-28-253.jpg
#   inflating: train_val_data/28/class-28-254.jpg
#   inflating: train_val_data/28/class-28-255.jpg
#   inflating: train_val_data/28/class-28-256.jpg
#   inflating: train_val_data/28/class-28-257.jpg
#   inflating: train_val_data/28/class-28-258.jpg
#   inflating: train_val_data/28/class-28-259.jpg
#   inflating: train_val_data/28/class-28-26.jpg
#   inflating: train_val_data/28/class-28-260.jpg
#   inflating: train_val_data/28/class-28-261.jpg
#   inflating: train_val_data/28/class-28-262.jpg
#   inflating: train_val_data/28/class-28-264.jpg
#   inflating: train_val_data/28/class-28-265.jpg
#   inflating: train_val_data/28/class-28-266.jpg
#   inflating: train_val_data/28/class-28-267.jpg
#   inflating: train_val_data/28/class-28-268.jpg
#   inflating: train_val_data/28/class-28-27.jpg
#   inflating: train_val_data/28/class-28-270.jpg
#   inflating: train_val_data/28/class-28-271.jpg
#   inflating: train_val_data/28/class-28-272.jpg
#   inflating: train_val_data/28/class-28-273.jpg
#   inflating: train_val_data/28/class-28-274.jpg
#   inflating: train_val_data/28/class-28-275.jpg
#   inflating: train_val_data/28/class-28-276.jpg
#   inflating: train_val_data/28/class-28-277.jpg
#   inflating: train_val_data/28/class-28-278.jpg
#   inflating: train_val_data/28/class-28-279.jpg
#   inflating: train_val_data/28/class-28-28.jpg
#   inflating: train_val_data/28/class-28-280.jpg
#   inflating: train_val_data/28/class-28-281.jpg
#   inflating: train_val_data/28/class-28-282.jpg
#   inflating: train_val_data/28/class-28-283.jpg
#   inflating: train_val_data/28/class-28-284.jpg
#   inflating: train_val_data/28/class-28-285.jpg
#   inflating: train_val_data/28/class-28-286.jpg
#   inflating: train_val_data/28/class-28-287.jpg
#   inflating: train_val_data/28/class-28-288.jpg
#   inflating: train_val_data/28/class-28-29.jpg
#   inflating: train_val_data/28/class-28-290.jpg
#   inflating: train_val_data/28/class-28-291.jpg
#   inflating: train_val_data/28/class-28-292.jpg
#   inflating: train_val_data/28/class-28-294.jpg
#   inflating: train_val_data/28/class-28-295.jpg
#   inflating: train_val_data/28/class-28-296.jpg
#   inflating: train_val_data/28/class-28-297.jpg
#   inflating: train_val_data/28/class-28-298.jpg
#   inflating: train_val_data/28/class-28-299.jpg
#   inflating: train_val_data/28/class-28-3.jpg
#   inflating: train_val_data/28/class-28-30.jpg
#   inflating: train_val_data/28/class-28-300.jpg
#   inflating: train_val_data/28/class-28-301.jpg
#   inflating: train_val_data/28/class-28-302.jpg
#   inflating: train_val_data/28/class-28-303.jpg
#   inflating: train_val_data/28/class-28-304.jpg
#   inflating: train_val_data/28/class-28-305.jpg
#   inflating: train_val_data/28/class-28-306.jpg
#   inflating: train_val_data/28/class-28-307.jpg
#   inflating: train_val_data/28/class-28-308.jpg
#   inflating: train_val_data/28/class-28-309.jpg
#   inflating: train_val_data/28/class-28-31.jpg
#   inflating: train_val_data/28/class-28-311.jpg
#   inflating: train_val_data/28/class-28-312.jpg
#   inflating: train_val_data/28/class-28-313.jpg
#   inflating: train_val_data/28/class-28-32.jpg
#   inflating: train_val_data/28/class-28-33.jpg
#   inflating: train_val_data/28/class-28-34.jpg
#   inflating: train_val_data/28/class-28-35.jpg
#   inflating: train_val_data/28/class-28-36.jpg
#   inflating: train_val_data/28/class-28-37.jpg
#   inflating: train_val_data/28/class-28-38.jpg
#   inflating: train_val_data/28/class-28-39.jpg
#   inflating: train_val_data/28/class-28-4.jpg
#   inflating: train_val_data/28/class-28-40.jpg
#   inflating: train_val_data/28/class-28-41.jpg
#   inflating: train_val_data/28/class-28-42.jpg
#   inflating: train_val_data/28/class-28-43.jpg
#   inflating: train_val_data/28/class-28-44.jpg
#   inflating: train_val_data/28/class-28-45.jpg
#   inflating: train_val_data/28/class-28-46.jpg
#   inflating: train_val_data/28/class-28-47.jpg
#   inflating: train_val_data/28/class-28-48.jpg
#   inflating: train_val_data/28/class-28-49.jpg
#   inflating: train_val_data/28/class-28-5.jpg
#   inflating: train_val_data/28/class-28-51.jpg
#   inflating: train_val_data/28/class-28-52.jpg
#   inflating: train_val_data/28/class-28-53.jpg
#   inflating: train_val_data/28/class-28-54.jpg
#   inflating: train_val_data/28/class-28-55.jpg
#   inflating: train_val_data/28/class-28-56.jpg
#   inflating: train_val_data/28/class-28-57.jpg
#   inflating: train_val_data/28/class-28-58.jpg
#   inflating: train_val_data/28/class-28-59.jpg
#   inflating: train_val_data/28/class-28-6.jpg
#   inflating: train_val_data/28/class-28-61.jpg
#   inflating: train_val_data/28/class-28-62.jpg
#   inflating: train_val_data/28/class-28-63.jpg
#   inflating: train_val_data/28/class-28-64.jpg
#   inflating: train_val_data/28/class-28-65.jpg
#   inflating: train_val_data/28/class-28-66.jpg
#   inflating: train_val_data/28/class-28-67.jpg
#   inflating: train_val_data/28/class-28-68.jpg
#   inflating: train_val_data/28/class-28-7.jpg
#   inflating: train_val_data/28/class-28-70.jpg
#   inflating: train_val_data/28/class-28-72.jpg
#   inflating: train_val_data/28/class-28-73.jpg
#   inflating: train_val_data/28/class-28-74.jpg
#   inflating: train_val_data/28/class-28-75.jpg
#   inflating: train_val_data/28/class-28-76.jpg
#   inflating: train_val_data/28/class-28-77.jpg
#   inflating: train_val_data/28/class-28-78.jpg
#   inflating: train_val_data/28/class-28-8.jpg
#   inflating: train_val_data/28/class-28-80.jpg
#   inflating: train_val_data/28/class-28-81.jpg
#   inflating: train_val_data/28/class-28-82.jpg
#   inflating: train_val_data/28/class-28-83.jpg
#   inflating: train_val_data/28/class-28-84.jpg
#   inflating: train_val_data/28/class-28-85.jpg
#   inflating: train_val_data/28/class-28-86.jpg
#   inflating: train_val_data/28/class-28-88.jpg
#   inflating: train_val_data/28/class-28-89.jpg
#   inflating: train_val_data/28/class-28-9.jpg
#   inflating: train_val_data/28/class-28-90.jpg
#   inflating: train_val_data/28/class-28-91.jpg
#   inflating: train_val_data/28/class-28-92.jpg
#   inflating: train_val_data/28/class-28-94.jpg
#   inflating: train_val_data/28/class-28-95.jpg
#   inflating: train_val_data/28/class-28-97.jpg
#   inflating: train_val_data/28/class-28-98.jpg
#   inflating: train_val_data/28/class-28-99.jpg
#    creating: train_val_data/29/
#   inflating: train_val_data/29/class-29-1.jpg
#   inflating: train_val_data/29/class-29-10.jpg
#   inflating: train_val_data/29/class-29-100.jpg
#   inflating: train_val_data/29/class-29-101.jpg
#   inflating: train_val_data/29/class-29-102.jpg
#   inflating: train_val_data/29/class-29-103.jpg
#   inflating: train_val_data/29/class-29-104.jpg
#   inflating: train_val_data/29/class-29-105.jpg
#   inflating: train_val_data/29/class-29-106.jpg
#   inflating: train_val_data/29/class-29-107.jpg
#   inflating: train_val_data/29/class-29-108.jpg
#   inflating: train_val_data/29/class-29-109.jpg
#   inflating: train_val_data/29/class-29-11.jpg
#   inflating: train_val_data/29/class-29-110.jpg
#   inflating: train_val_data/29/class-29-111.jpg
#   inflating: train_val_data/29/class-29-112.jpg
#   inflating: train_val_data/29/class-29-113.jpg
#   inflating: train_val_data/29/class-29-114.jpg
#   inflating: train_val_data/29/class-29-115.jpg
#   inflating: train_val_data/29/class-29-116.jpg
#   inflating: train_val_data/29/class-29-118.jpg
#   inflating: train_val_data/29/class-29-119.jpg
#   inflating: train_val_data/29/class-29-12.jpg
#   inflating: train_val_data/29/class-29-120.jpg
#   inflating: train_val_data/29/class-29-121.jpg
#   inflating: train_val_data/29/class-29-122.jpg
#   inflating: train_val_data/29/class-29-123.jpg
#   inflating: train_val_data/29/class-29-124.jpg
#   inflating: train_val_data/29/class-29-125.jpg
#   inflating: train_val_data/29/class-29-127.jpg
#   inflating: train_val_data/29/class-29-128.jpg
#   inflating: train_val_data/29/class-29-129.jpg
#   inflating: train_val_data/29/class-29-13.jpg
#   inflating: train_val_data/29/class-29-130.jpg
#   inflating: train_val_data/29/class-29-131.jpg
#   inflating: train_val_data/29/class-29-132.jpg
#   inflating: train_val_data/29/class-29-133.jpg
#   inflating: train_val_data/29/class-29-134.jpg
#   inflating: train_val_data/29/class-29-135.jpg
#   inflating: train_val_data/29/class-29-136.jpg
#   inflating: train_val_data/29/class-29-137.jpg
#   inflating: train_val_data/29/class-29-138.jpg
#   inflating: train_val_data/29/class-29-139.jpg
#   inflating: train_val_data/29/class-29-14.jpg
#   inflating: train_val_data/29/class-29-140.jpg
#   inflating: train_val_data/29/class-29-141.jpg
#   inflating: train_val_data/29/class-29-142.jpg
#   inflating: train_val_data/29/class-29-143.jpg
#   inflating: train_val_data/29/class-29-144.jpg
#   inflating: train_val_data/29/class-29-145.jpg
#   inflating: train_val_data/29/class-29-147.jpg
#   inflating: train_val_data/29/class-29-148.jpg
#   inflating: train_val_data/29/class-29-149.jpg
#   inflating: train_val_data/29/class-29-15.jpg
#   inflating: train_val_data/29/class-29-150.jpg
#   inflating: train_val_data/29/class-29-151.jpg
#   inflating: train_val_data/29/class-29-153.jpg
#   inflating: train_val_data/29/class-29-154.jpg
#   inflating: train_val_data/29/class-29-155.jpg
#   inflating: train_val_data/29/class-29-156.jpg
#   inflating: train_val_data/29/class-29-158.jpg
#   inflating: train_val_data/29/class-29-159.jpg
#   inflating: train_val_data/29/class-29-160.jpg
#   inflating: train_val_data/29/class-29-161.jpg
#   inflating: train_val_data/29/class-29-162.jpg
#   inflating: train_val_data/29/class-29-163.jpg
#   inflating: train_val_data/29/class-29-164.jpg
#   inflating: train_val_data/29/class-29-166.jpg
#   inflating: train_val_data/29/class-29-167.jpg
#   inflating: train_val_data/29/class-29-168.jpg
#   inflating: train_val_data/29/class-29-169.jpg
#   inflating: train_val_data/29/class-29-17.jpg
#   inflating: train_val_data/29/class-29-170.jpg
#   inflating: train_val_data/29/class-29-171.jpg
#   inflating: train_val_data/29/class-29-172.jpg
#   inflating: train_val_data/29/class-29-173.jpg
#   inflating: train_val_data/29/class-29-175.jpg
#   inflating: train_val_data/29/class-29-176.jpg
#   inflating: train_val_data/29/class-29-177.jpg
#   inflating: train_val_data/29/class-29-178.jpg
#   inflating: train_val_data/29/class-29-179.jpg
#   inflating: train_val_data/29/class-29-180.jpg
#   inflating: train_val_data/29/class-29-181.jpg
#   inflating: train_val_data/29/class-29-182.jpg
#   inflating: train_val_data/29/class-29-183.jpg
#   inflating: train_val_data/29/class-29-184.jpg
#   inflating: train_val_data/29/class-29-188.jpg
#   inflating: train_val_data/29/class-29-189.jpg
#   inflating: train_val_data/29/class-29-19.jpg
#   inflating: train_val_data/29/class-29-190.jpg
#   inflating: train_val_data/29/class-29-191.jpg
#   inflating: train_val_data/29/class-29-192.jpg
#   inflating: train_val_data/29/class-29-193.jpg
#   inflating: train_val_data/29/class-29-194.jpg
#   inflating: train_val_data/29/class-29-195.jpg
#   inflating: train_val_data/29/class-29-196.jpg
#   inflating: train_val_data/29/class-29-197.jpg
#   inflating: train_val_data/29/class-29-198.jpg
#   inflating: train_val_data/29/class-29-199.jpg
#   inflating: train_val_data/29/class-29-2.jpg
#   inflating: train_val_data/29/class-29-20.jpg
#   inflating: train_val_data/29/class-29-200.jpg
#   inflating: train_val_data/29/class-29-202.jpg
#   inflating: train_val_data/29/class-29-203.jpg
#   inflating: train_val_data/29/class-29-204.jpg
#   inflating: train_val_data/29/class-29-205.jpg
#   inflating: train_val_data/29/class-29-206.jpg
#   inflating: train_val_data/29/class-29-207.jpg
#   inflating: train_val_data/29/class-29-21.jpg
#   inflating: train_val_data/29/class-29-210.jpg
#   inflating: train_val_data/29/class-29-211.jpg
#   inflating: train_val_data/29/class-29-212.jpg
#   inflating: train_val_data/29/class-29-213.jpg
#   inflating: train_val_data/29/class-29-214.jpg
#   inflating: train_val_data/29/class-29-215.jpg
#   inflating: train_val_data/29/class-29-217.jpg
#   inflating: train_val_data/29/class-29-218.jpg
#   inflating: train_val_data/29/class-29-219.jpg
#   inflating: train_val_data/29/class-29-22.jpg
#   inflating: train_val_data/29/class-29-220.jpg
#   inflating: train_val_data/29/class-29-221.jpg
#   inflating: train_val_data/29/class-29-222.jpg
#   inflating: train_val_data/29/class-29-223.jpg
#   inflating: train_val_data/29/class-29-224.jpg
#   inflating: train_val_data/29/class-29-225.jpg
#   inflating: train_val_data/29/class-29-226.jpg
#   inflating: train_val_data/29/class-29-227.jpg
#   inflating: train_val_data/29/class-29-228.jpg
#   inflating: train_val_data/29/class-29-229.jpg
#   inflating: train_val_data/29/class-29-230.jpg
#   inflating: train_val_data/29/class-29-231.jpg
#   inflating: train_val_data/29/class-29-232.jpg
#   inflating: train_val_data/29/class-29-233.jpg
#   inflating: train_val_data/29/class-29-234.jpg
#   inflating: train_val_data/29/class-29-235.jpg
#   inflating: train_val_data/29/class-29-236.jpg
#   inflating: train_val_data/29/class-29-237.jpg
#   inflating: train_val_data/29/class-29-238.jpg
#   inflating: train_val_data/29/class-29-239.jpg
#   inflating: train_val_data/29/class-29-24.jpg
#   inflating: train_val_data/29/class-29-240.jpg
#   inflating: train_val_data/29/class-29-241.jpg
#   inflating: train_val_data/29/class-29-242.jpg
#   inflating: train_val_data/29/class-29-243.jpg
#   inflating: train_val_data/29/class-29-244.jpg
#   inflating: train_val_data/29/class-29-245.jpg
#   inflating: train_val_data/29/class-29-246.jpg
#   inflating: train_val_data/29/class-29-247.jpg
#   inflating: train_val_data/29/class-29-248.jpg
#   inflating: train_val_data/29/class-29-249.jpg
#   inflating: train_val_data/29/class-29-25.jpg
#   inflating: train_val_data/29/class-29-250.jpg
#   inflating: train_val_data/29/class-29-251.jpg
#   inflating: train_val_data/29/class-29-252.jpg
#   inflating: train_val_data/29/class-29-253.jpg
#   inflating: train_val_data/29/class-29-254.jpg
#   inflating: train_val_data/29/class-29-255.jpg
#   inflating: train_val_data/29/class-29-256.jpg
#   inflating: train_val_data/29/class-29-257.jpg
#   inflating: train_val_data/29/class-29-258.jpg
#   inflating: train_val_data/29/class-29-259.jpg
#   inflating: train_val_data/29/class-29-26.jpg
#   inflating: train_val_data/29/class-29-260.jpg
#   inflating: train_val_data/29/class-29-261.jpg
#   inflating: train_val_data/29/class-29-262.jpg
#   inflating: train_val_data/29/class-29-263.jpg
#   inflating: train_val_data/29/class-29-264.jpg
#   inflating: train_val_data/29/class-29-265.jpg
#   inflating: train_val_data/29/class-29-266.jpg
#   inflating: train_val_data/29/class-29-267.jpg
#   inflating: train_val_data/29/class-29-268.jpg
#   inflating: train_val_data/29/class-29-269.jpg
#   inflating: train_val_data/29/class-29-270.jpg
#   inflating: train_val_data/29/class-29-271.jpg
#   inflating: train_val_data/29/class-29-272.jpg
#   inflating: train_val_data/29/class-29-273.jpg
#   inflating: train_val_data/29/class-29-274.jpg
#   inflating: train_val_data/29/class-29-275.jpg
#   inflating: train_val_data/29/class-29-276.jpg
#   inflating: train_val_data/29/class-29-277.jpg
#   inflating: train_val_data/29/class-29-278.jpg
#   inflating: train_val_data/29/class-29-279.jpg
#   inflating: train_val_data/29/class-29-28.jpg
#   inflating: train_val_data/29/class-29-280.jpg
#   inflating: train_val_data/29/class-29-281.jpg
#   inflating: train_val_data/29/class-29-282.jpg
#   inflating: train_val_data/29/class-29-283.jpg
#   inflating: train_val_data/29/class-29-284.jpg
#   inflating: train_val_data/29/class-29-285.jpg
#   inflating: train_val_data/29/class-29-286.jpg
#   inflating: train_val_data/29/class-29-287.jpg
#   inflating: train_val_data/29/class-29-288.jpg
#   inflating: train_val_data/29/class-29-289.jpg
#   inflating: train_val_data/29/class-29-29.jpg
#   inflating: train_val_data/29/class-29-290.jpg
#   inflating: train_val_data/29/class-29-293.jpg
#   inflating: train_val_data/29/class-29-294.jpg
#   inflating: train_val_data/29/class-29-295.jpg
#   inflating: train_val_data/29/class-29-296.jpg
#   inflating: train_val_data/29/class-29-297.jpg
#   inflating: train_val_data/29/class-29-298.jpg
#   inflating: train_val_data/29/class-29-3.jpg
#   inflating: train_val_data/29/class-29-300.jpg
#   inflating: train_val_data/29/class-29-301.jpg
#   inflating: train_val_data/29/class-29-31.jpg
#   inflating: train_val_data/29/class-29-33.jpg
#   inflating: train_val_data/29/class-29-34.jpg
#   inflating: train_val_data/29/class-29-35.jpg
#   inflating: train_val_data/29/class-29-36.jpg
#   inflating: train_val_data/29/class-29-37.jpg
#   inflating: train_val_data/29/class-29-38.jpg
#   inflating: train_val_data/29/class-29-39.jpg
#   inflating: train_val_data/29/class-29-4.jpg
#   inflating: train_val_data/29/class-29-40.jpg
#   inflating: train_val_data/29/class-29-41.jpg
#   inflating: train_val_data/29/class-29-42.jpg
#   inflating: train_val_data/29/class-29-43.jpg
#   inflating: train_val_data/29/class-29-45.jpg
#   inflating: train_val_data/29/class-29-46.jpg
#   inflating: train_val_data/29/class-29-48.jpg
#   inflating: train_val_data/29/class-29-49.jpg
#   inflating: train_val_data/29/class-29-5.jpg
#   inflating: train_val_data/29/class-29-50.jpg
#   inflating: train_val_data/29/class-29-51.jpg
#   inflating: train_val_data/29/class-29-52.jpg
#   inflating: train_val_data/29/class-29-53.jpg
#   inflating: train_val_data/29/class-29-54.jpg
#   inflating: train_val_data/29/class-29-55.jpg
#   inflating: train_val_data/29/class-29-56.jpg
#   inflating: train_val_data/29/class-29-58.jpg
#   inflating: train_val_data/29/class-29-59.jpg
#   inflating: train_val_data/29/class-29-6.jpg
#   inflating: train_val_data/29/class-29-60.jpg
#   inflating: train_val_data/29/class-29-62.jpg
#   inflating: train_val_data/29/class-29-63.jpg
#   inflating: train_val_data/29/class-29-64.jpg
#   inflating: train_val_data/29/class-29-65.jpg
#   inflating: train_val_data/29/class-29-66.jpg
#   inflating: train_val_data/29/class-29-67.jpg
#   inflating: train_val_data/29/class-29-68.jpg
#   inflating: train_val_data/29/class-29-69.jpg
#   inflating: train_val_data/29/class-29-7.jpg
#   inflating: train_val_data/29/class-29-70.jpg
#   inflating: train_val_data/29/class-29-71.jpg
#   inflating: train_val_data/29/class-29-72.jpg
#   inflating: train_val_data/29/class-29-73.jpg
#   inflating: train_val_data/29/class-29-74.jpg
#   inflating: train_val_data/29/class-29-75.jpg
#   inflating: train_val_data/29/class-29-76.jpg
#   inflating: train_val_data/29/class-29-77.jpg
#   inflating: train_val_data/29/class-29-78.jpg
#   inflating: train_val_data/29/class-29-79.jpg
#   inflating: train_val_data/29/class-29-8.jpg
#   inflating: train_val_data/29/class-29-80.jpg
#   inflating: train_val_data/29/class-29-81.jpg
#   inflating: train_val_data/29/class-29-82.jpg
#   inflating: train_val_data/29/class-29-83.jpg
#   inflating: train_val_data/29/class-29-84.jpg
#   inflating: train_val_data/29/class-29-86.jpg
#   inflating: train_val_data/29/class-29-87.jpg
#   inflating: train_val_data/29/class-29-88.jpg
#   inflating: train_val_data/29/class-29-89.jpg
#   inflating: train_val_data/29/class-29-9.jpg
#   inflating: train_val_data/29/class-29-90.jpg
#   inflating: train_val_data/29/class-29-91.jpg
#   inflating: train_val_data/29/class-29-93.jpg
#   inflating: train_val_data/29/class-29-94.jpg
#   inflating: train_val_data/29/class-29-95.jpg
#   inflating: train_val_data/29/class-29-97.jpg
#   inflating: train_val_data/29/class-29-98.jpg
#   inflating: train_val_data/29/class-29-99.jpg
#    creating: train_val_data/3/
#   inflating: train_val_data/3/class-3-1.jpg
#   inflating: train_val_data/3/class-3-100.jpg
#   inflating: train_val_data/3/class-3-101.jpg
#   inflating: train_val_data/3/class-3-102.jpg
#   inflating: train_val_data/3/class-3-103.jpg
#   inflating: train_val_data/3/class-3-104.jpg
#   inflating: train_val_data/3/class-3-105.jpg
#   inflating: train_val_data/3/class-3-106.jpg
#   inflating: train_val_data/3/class-3-107.jpg
#   inflating: train_val_data/3/class-3-108.jpg
#   inflating: train_val_data/3/class-3-109.jpg
#   inflating: train_val_data/3/class-3-11.jpg
#   inflating: train_val_data/3/class-3-110.jpg
#   inflating: train_val_data/3/class-3-111.jpg
#   inflating: train_val_data/3/class-3-112.jpg
#   inflating: train_val_data/3/class-3-113.jpg
#   inflating: train_val_data/3/class-3-115.jpg
#   inflating: train_val_data/3/class-3-117.jpg
#   inflating: train_val_data/3/class-3-118.jpg
#   inflating: train_val_data/3/class-3-119.jpg
#   inflating: train_val_data/3/class-3-12.jpg
#   inflating: train_val_data/3/class-3-120.jpg
#   inflating: train_val_data/3/class-3-121.jpg
#   inflating: train_val_data/3/class-3-122.jpg
#   inflating: train_val_data/3/class-3-123.jpg
#   inflating: train_val_data/3/class-3-124.jpg
#   inflating: train_val_data/3/class-3-125.jpg
#   inflating: train_val_data/3/class-3-126.jpg
#   inflating: train_val_data/3/class-3-127.jpg
#   inflating: train_val_data/3/class-3-128.jpg
#   inflating: train_val_data/3/class-3-129.jpg
#   inflating: train_val_data/3/class-3-13.jpg
#   inflating: train_val_data/3/class-3-130.jpg
#   inflating: train_val_data/3/class-3-131.jpg
#   inflating: train_val_data/3/class-3-132.jpg
#   inflating: train_val_data/3/class-3-135.jpg
#   inflating: train_val_data/3/class-3-136.jpg
#   inflating: train_val_data/3/class-3-137.jpg
#   inflating: train_val_data/3/class-3-138.jpg
#   inflating: train_val_data/3/class-3-139.jpg
#   inflating: train_val_data/3/class-3-14.jpg
#   inflating: train_val_data/3/class-3-140.jpg
#   inflating: train_val_data/3/class-3-141.jpg
#   inflating: train_val_data/3/class-3-142.jpg
#   inflating: train_val_data/3/class-3-143.jpg
#   inflating: train_val_data/3/class-3-144.jpg
#   inflating: train_val_data/3/class-3-145.jpg
#   inflating: train_val_data/3/class-3-146.jpg
#   inflating: train_val_data/3/class-3-147.jpg
#   inflating: train_val_data/3/class-3-148.jpg
#   inflating: train_val_data/3/class-3-15.jpg
#   inflating: train_val_data/3/class-3-150.jpg
#   inflating: train_val_data/3/class-3-151.jpg
#   inflating: train_val_data/3/class-3-152.jpg
#   inflating: train_val_data/3/class-3-153.jpg
#   inflating: train_val_data/3/class-3-155.jpg
#   inflating: train_val_data/3/class-3-156.jpg
#   inflating: train_val_data/3/class-3-157.jpg
#   inflating: train_val_data/3/class-3-158.jpg
#   inflating: train_val_data/3/class-3-159.jpg
#   inflating: train_val_data/3/class-3-16.jpg
#   inflating: train_val_data/3/class-3-160.jpg
#   inflating: train_val_data/3/class-3-161.jpg
#   inflating: train_val_data/3/class-3-162.jpg
#   inflating: train_val_data/3/class-3-163.jpg
#   inflating: train_val_data/3/class-3-165.jpg
#   inflating: train_val_data/3/class-3-166.jpg
#   inflating: train_val_data/3/class-3-167.jpg
#   inflating: train_val_data/3/class-3-168.jpg
#   inflating: train_val_data/3/class-3-169.jpg
#   inflating: train_val_data/3/class-3-17.jpg
#   inflating: train_val_data/3/class-3-170.jpg
#   inflating: train_val_data/3/class-3-171.jpg
#   inflating: train_val_data/3/class-3-172.jpg
#   inflating: train_val_data/3/class-3-173.jpg
#   inflating: train_val_data/3/class-3-174.jpg
#   inflating: train_val_data/3/class-3-175.jpg
#   inflating: train_val_data/3/class-3-176.jpg
#   inflating: train_val_data/3/class-3-177.jpg
#   inflating: train_val_data/3/class-3-178.jpg
#   inflating: train_val_data/3/class-3-179.jpg
#   inflating: train_val_data/3/class-3-18.jpg
#   inflating: train_val_data/3/class-3-180.jpg
#   inflating: train_val_data/3/class-3-181.jpg
#   inflating: train_val_data/3/class-3-182.jpg
#   inflating: train_val_data/3/class-3-183.jpg
#   inflating: train_val_data/3/class-3-184.jpg
#   inflating: train_val_data/3/class-3-185.jpg
#   inflating: train_val_data/3/class-3-186.jpg
#   inflating: train_val_data/3/class-3-187.jpg
#   inflating: train_val_data/3/class-3-188.jpg
#   inflating: train_val_data/3/class-3-189.jpg
#   inflating: train_val_data/3/class-3-19.jpg
#   inflating: train_val_data/3/class-3-190.jpg
#   inflating: train_val_data/3/class-3-191.jpg
#   inflating: train_val_data/3/class-3-192.jpg
#   inflating: train_val_data/3/class-3-193.jpg
#   inflating: train_val_data/3/class-3-194.jpg
#   inflating: train_val_data/3/class-3-195.jpg
#   inflating: train_val_data/3/class-3-196.jpg
#   inflating: train_val_data/3/class-3-198.jpg
#   inflating: train_val_data/3/class-3-199.jpg
#   inflating: train_val_data/3/class-3-2.jpg
#   inflating: train_val_data/3/class-3-200.jpg
#   inflating: train_val_data/3/class-3-201.jpg
#   inflating: train_val_data/3/class-3-202.jpg
#   inflating: train_val_data/3/class-3-203.jpg
#   inflating: train_val_data/3/class-3-204.jpg
#   inflating: train_val_data/3/class-3-205.jpg
#   inflating: train_val_data/3/class-3-206.jpg
#   inflating: train_val_data/3/class-3-207.jpg
#   inflating: train_val_data/3/class-3-208.jpg
#   inflating: train_val_data/3/class-3-209.jpg
#   inflating: train_val_data/3/class-3-210.jpg
#   inflating: train_val_data/3/class-3-212.jpg
#   inflating: train_val_data/3/class-3-213.jpg
#   inflating: train_val_data/3/class-3-214.jpg
#   inflating: train_val_data/3/class-3-215.jpg
#   inflating: train_val_data/3/class-3-216.jpg
#   inflating: train_val_data/3/class-3-217.jpg
#   inflating: train_val_data/3/class-3-218.jpg
#   inflating: train_val_data/3/class-3-219.jpg
#   inflating: train_val_data/3/class-3-22.jpg
#   inflating: train_val_data/3/class-3-220.jpg
#   inflating: train_val_data/3/class-3-221.jpg
#   inflating: train_val_data/3/class-3-222.jpg
#   inflating: train_val_data/3/class-3-223.jpg
#   inflating: train_val_data/3/class-3-224.jpg
#   inflating: train_val_data/3/class-3-226.jpg
#   inflating: train_val_data/3/class-3-227.jpg
#   inflating: train_val_data/3/class-3-228.jpg
#   inflating: train_val_data/3/class-3-229.jpg
#   inflating: train_val_data/3/class-3-23.jpg
#   inflating: train_val_data/3/class-3-231.jpg
#   inflating: train_val_data/3/class-3-232.jpg
#   inflating: train_val_data/3/class-3-233.jpg
#   inflating: train_val_data/3/class-3-234.jpg
#   inflating: train_val_data/3/class-3-235.jpg
#   inflating: train_val_data/3/class-3-236.jpg
#   inflating: train_val_data/3/class-3-237.jpg
#   inflating: train_val_data/3/class-3-238.jpg
#   inflating: train_val_data/3/class-3-239.jpg
#   inflating: train_val_data/3/class-3-24.jpg
#   inflating: train_val_data/3/class-3-240.jpg
#   inflating: train_val_data/3/class-3-241.jpg
# ...
#   inflating: train_val_data/8/class-8-294.jpg
#   inflating: train_val_data/8/class-8-295.jpg
#   inflating: train_val_data/8/class-8-296.jpg
#   inflating: train_val_data/8/class-8-297.jpg
#   inflating: train_val_data/8/class-8-298.jpg
#   inflating: train_val_data/8/class-8-299.jpg
#   inflating: train_val_data/8/class-8-3.jpg
#   inflating: train_val_data/8/class-8-30.jpg
#   inflating: train_val_data/8/class-8-31.jpg
#   inflating: train_val_data/8/class-8-32.jpg
#   inflating: train_val_data/8/class-8-34.jpg
#   inflating: train_val_data/8/class-8-35.jpg
#   inflating: train_val_data/8/class-8-36.jpg
#   inflating: train_val_data/8/class-8-37.jpg
#   inflating: train_val_data/8/class-8-38.jpg
#   inflating: train_val_data/8/class-8-39.jpg
#   inflating: train_val_data/8/class-8-4.jpg
#   inflating: train_val_data/8/class-8-40.jpg
#   inflating: train_val_data/8/class-8-41.jpg
#   inflating: train_val_data/8/class-8-42.jpg
#   inflating: train_val_data/8/class-8-44.jpg
#   inflating: train_val_data/8/class-8-45.jpg
#   inflating: train_val_data/8/class-8-46.jpg
#   inflating: train_val_data/8/class-8-47.jpg
#   inflating: train_val_data/8/class-8-5.jpg
#   inflating: train_val_data/8/class-8-50.jpg
#   inflating: train_val_data/8/class-8-51.jpg
#   inflating: train_val_data/8/class-8-52.jpg
#   inflating: train_val_data/8/class-8-53.jpg
#   inflating: train_val_data/8/class-8-54.jpg
#   inflating: train_val_data/8/class-8-55.jpg
#   inflating: train_val_data/8/class-8-56.jpg
#   inflating: train_val_data/8/class-8-57.jpg
#   inflating: train_val_data/8/class-8-58.jpg
#   inflating: train_val_data/8/class-8-59.jpg
#   inflating: train_val_data/8/class-8-6.jpg
#   inflating: train_val_data/8/class-8-61.jpg
#   inflating: train_val_data/8/class-8-62.jpg
#   inflating: train_val_data/8/class-8-63.jpg
#   inflating: train_val_data/8/class-8-65.jpg
#   inflating: train_val_data/8/class-8-66.jpg
#   inflating: train_val_data/8/class-8-67.jpg
#   inflating: train_val_data/8/class-8-69.jpg
#   inflating: train_val_data/8/class-8-7.jpg
#   inflating: train_val_data/8/class-8-70.jpg
#   inflating: train_val_data/8/class-8-71.jpg
#   inflating: train_val_data/8/class-8-72.jpg
#   inflating: train_val_data/8/class-8-73.jpg
#   inflating: train_val_data/8/class-8-74.jpg
#   inflating: train_val_data/8/class-8-75.jpg
#   inflating: train_val_data/8/class-8-77.jpg
#   inflating: train_val_data/8/class-8-78.jpg
#   inflating: train_val_data/8/class-8-79.jpg
#   inflating: train_val_data/8/class-8-8.jpg
#   inflating: train_val_data/8/class-8-80.jpg
#   inflating: train_val_data/8/class-8-81.jpg
#   inflating: train_val_data/8/class-8-82.jpg
#   inflating: train_val_data/8/class-8-83.jpg
#   inflating: train_val_data/8/class-8-84.jpg
#   inflating: train_val_data/8/class-8-85.jpg
#   inflating: train_val_data/8/class-8-86.jpg
#   inflating: train_val_data/8/class-8-87.jpg
#   inflating: train_val_data/8/class-8-89.jpg
#   inflating: train_val_data/8/class-8-9.jpg
#   inflating: train_val_data/8/class-8-90.jpg
#   inflating: train_val_data/8/class-8-91.jpg
#   inflating: train_val_data/8/class-8-92.jpg
#   inflating: train_val_data/8/class-8-93.jpg
#   inflating: train_val_data/8/class-8-95.jpg
#   inflating: train_val_data/8/class-8-96.jpg
#   inflating: train_val_data/8/class-8-97.jpg
#   inflating: train_val_data/8/class-8-98.jpg
#   inflating: train_val_data/8/class-8-99.jpg
#    creating: train_val_data/9/
#   inflating: train_val_data/9/class-9-1.jpg
#   inflating: train_val_data/9/class-9-10.jpg
#   inflating: train_val_data/9/class-9-100.jpg
#   inflating: train_val_data/9/class-9-101.jpg
#   inflating: train_val_data/9/class-9-102.jpg
#   inflating: train_val_data/9/class-9-103.jpg
#   inflating: train_val_data/9/class-9-104.jpg
#   inflating: train_val_data/9/class-9-105.jpg
#   inflating: train_val_data/9/class-9-106.jpg
#   inflating: train_val_data/9/class-9-107.jpg
#   inflating: train_val_data/9/class-9-108.jpg
#   inflating: train_val_data/9/class-9-109.jpg
#   inflating: train_val_data/9/class-9-11.jpg
#   inflating: train_val_data/9/class-9-110.jpg
#   inflating: train_val_data/9/class-9-111.jpg
#   inflating: train_val_data/9/class-9-112.jpg
#   inflating: train_val_data/9/class-9-113.jpg
#   inflating: train_val_data/9/class-9-114.jpg
#   inflating: train_val_data/9/class-9-115.jpg
#   inflating: train_val_data/9/class-9-116.jpg
#   inflating: train_val_data/9/class-9-117.jpg
#   inflating: train_val_data/9/class-9-119.jpg
#   inflating: train_val_data/9/class-9-12.jpg
#   inflating: train_val_data/9/class-9-120.jpg
#   inflating: train_val_data/9/class-9-121.jpg
#   inflating: train_val_data/9/class-9-122.jpg
#   inflating: train_val_data/9/class-9-123.jpg
#   inflating: train_val_data/9/class-9-124.jpg
#   inflating: train_val_data/9/class-9-125.jpg
#   inflating: train_val_data/9/class-9-126.jpg
#   inflating: train_val_data/9/class-9-127.jpg
#   inflating: train_val_data/9/class-9-128.jpg
#   inflating: train_val_data/9/class-9-129.jpg
#   inflating: train_val_data/9/class-9-13.jpg
#   inflating: train_val_data/9/class-9-130.jpg
#   inflating: train_val_data/9/class-9-131.jpg
#   inflating: train_val_data/9/class-9-133.jpg
#   inflating: train_val_data/9/class-9-134.jpg
#   inflating: train_val_data/9/class-9-135.jpg
#   inflating: train_val_data/9/class-9-136.jpg
#   inflating: train_val_data/9/class-9-137.jpg
#   inflating: train_val_data/9/class-9-138.jpg
#   inflating: train_val_data/9/class-9-139.jpg
#   inflating: train_val_data/9/class-9-14.jpg
#   inflating: train_val_data/9/class-9-140.jpg
#   inflating: train_val_data/9/class-9-141.jpg
#   inflating: train_val_data/9/class-9-142.jpg
#   inflating: train_val_data/9/class-9-143.jpg
#   inflating: train_val_data/9/class-9-144.jpg
#   inflating: train_val_data/9/class-9-145.jpg
#   inflating: train_val_data/9/class-9-146.jpg
#   inflating: train_val_data/9/class-9-147.jpg
#   inflating: train_val_data/9/class-9-149.jpg
#   inflating: train_val_data/9/class-9-15.jpg
#   inflating: train_val_data/9/class-9-150.jpg
#   inflating: train_val_data/9/class-9-151.jpg
#   inflating: train_val_data/9/class-9-152.jpg
#   inflating: train_val_data/9/class-9-153.jpg
#   inflating: train_val_data/9/class-9-154.jpg
#   inflating: train_val_data/9/class-9-156.jpg
#   inflating: train_val_data/9/class-9-157.jpg
#   inflating: train_val_data/9/class-9-158.jpg
#   inflating: train_val_data/9/class-9-159.jpg
#   inflating: train_val_data/9/class-9-16.jpg
#   inflating: train_val_data/9/class-9-160.jpg
#   inflating: train_val_data/9/class-9-161.jpg
#   inflating: train_val_data/9/class-9-162.jpg
#   inflating: train_val_data/9/class-9-163.jpg
#   inflating: train_val_data/9/class-9-164.jpg
#   inflating: train_val_data/9/class-9-165.jpg
#   inflating: train_val_data/9/class-9-166.jpg
#   inflating: train_val_data/9/class-9-168.jpg
#   inflating: train_val_data/9/class-9-169.jpg
#   inflating: train_val_data/9/class-9-17.jpg
#   inflating: train_val_data/9/class-9-170.jpg
#   inflating: train_val_data/9/class-9-171.jpg
#   inflating: train_val_data/9/class-9-172.jpg
#   inflating: train_val_data/9/class-9-173.jpg
#   inflating: train_val_data/9/class-9-174.jpg
#   inflating: train_val_data/9/class-9-175.jpg
#   inflating: train_val_data/9/class-9-176.jpg
#   inflating: train_val_data/9/class-9-178.jpg
#   inflating: train_val_data/9/class-9-179.jpg
#   inflating: train_val_data/9/class-9-180.jpg
#   inflating: train_val_data/9/class-9-181.jpg
#   inflating: train_val_data/9/class-9-182.jpg
#   inflating: train_val_data/9/class-9-184.jpg
#   inflating: train_val_data/9/class-9-185.jpg
#   inflating: train_val_data/9/class-9-186.jpg
#   inflating: train_val_data/9/class-9-187.jpg
#   inflating: train_val_data/9/class-9-189.jpg
#   inflating: train_val_data/9/class-9-19.jpg
#   inflating: train_val_data/9/class-9-190.jpg
#   inflating: train_val_data/9/class-9-191.jpg
#   inflating: train_val_data/9/class-9-192.jpg
#   inflating: train_val_data/9/class-9-193.jpg
#   inflating: train_val_data/9/class-9-194.jpg
#   inflating: train_val_data/9/class-9-195.jpg
#   inflating: train_val_data/9/class-9-196.jpg
#   inflating: train_val_data/9/class-9-197.jpg
#   inflating: train_val_data/9/class-9-198.jpg
#   inflating: train_val_data/9/class-9-199.jpg
#   inflating: train_val_data/9/class-9-2.jpg
#   inflating: train_val_data/9/class-9-20.jpg
#   inflating: train_val_data/9/class-9-200.jpg
#   inflating: train_val_data/9/class-9-202.jpg
#   inflating: train_val_data/9/class-9-203.jpg
#   inflating: train_val_data/9/class-9-204.jpg
#   inflating: train_val_data/9/class-9-205.jpg
#   inflating: train_val_data/9/class-9-206.jpg
#   inflating: train_val_data/9/class-9-207.jpg
#   inflating: train_val_data/9/class-9-208.jpg
#   inflating: train_val_data/9/class-9-209.jpg
#   inflating: train_val_data/9/class-9-21.jpg
#   inflating: train_val_data/9/class-9-210.jpg
#   inflating: train_val_data/9/class-9-211.jpg
#   inflating: train_val_data/9/class-9-212.jpg
#   inflating: train_val_data/9/class-9-213.jpg
#   inflating: train_val_data/9/class-9-215.jpg
#   inflating: train_val_data/9/class-9-216.jpg
#   inflating: train_val_data/9/class-9-217.jpg
#   inflating: train_val_data/9/class-9-218.jpg
#   inflating: train_val_data/9/class-9-219.jpg
#   inflating: train_val_data/9/class-9-22.jpg
#   inflating: train_val_data/9/class-9-220.jpg
#   inflating: train_val_data/9/class-9-221.jpg
#   inflating: train_val_data/9/class-9-222.jpg
#   inflating: train_val_data/9/class-9-224.jpg
#   inflating: train_val_data/9/class-9-225.jpg
#   inflating: train_val_data/9/class-9-226.jpg
#   inflating: train_val_data/9/class-9-227.jpg
#   inflating: train_val_data/9/class-9-228.jpg
#   inflating: train_val_data/9/class-9-229.jpg
#   inflating: train_val_data/9/class-9-23.jpg
#   inflating: train_val_data/9/class-9-230.jpg
#   inflating: train_val_data/9/class-9-231.jpg
#   inflating: train_val_data/9/class-9-232.jpg
#   inflating: train_val_data/9/class-9-233.jpg
#   inflating: train_val_data/9/class-9-234.jpg
#   inflating: train_val_data/9/class-9-235.jpg
#   inflating: train_val_data/9/class-9-236.jpg
#   inflating: train_val_data/9/class-9-237.jpg
#   inflating: train_val_data/9/class-9-238.jpg
#   inflating: train_val_data/9/class-9-24.jpg
#   inflating: train_val_data/9/class-9-240.jpg
#   inflating: train_val_data/9/class-9-241.jpg
#   inflating: train_val_data/9/class-9-242.jpg
#   inflating: train_val_data/9/class-9-243.jpg
#   inflating: train_val_data/9/class-9-244.jpg
#   inflating: train_val_data/9/class-9-245.jpg
#   inflating: train_val_data/9/class-9-246.jpg
#   inflating: train_val_data/9/class-9-247.jpg
#   inflating: train_val_data/9/class-9-248.jpg
#   inflating: train_val_data/9/class-9-249.jpg
#   inflating: train_val_data/9/class-9-25.jpg
#   inflating: train_val_data/9/class-9-250.jpg
#   inflating: train_val_data/9/class-9-251.jpg
#   inflating: train_val_data/9/class-9-252.jpg
#   inflating: train_val_data/9/class-9-253.jpg
#   inflating: train_val_data/9/class-9-254.jpg
#   inflating: train_val_data/9/class-9-255.jpg
#   inflating: train_val_data/9/class-9-256.jpg
#   inflating: train_val_data/9/class-9-257.jpg
#   inflating: train_val_data/9/class-9-258.jpg
#   inflating: train_val_data/9/class-9-259.jpg
#   inflating: train_val_data/9/class-9-26.jpg
#   inflating: train_val_data/9/class-9-260.jpg
#   inflating: train_val_data/9/class-9-262.jpg
#   inflating: train_val_data/9/class-9-263.jpg
#   inflating: train_val_data/9/class-9-264.jpg
#   inflating: train_val_data/9/class-9-265.jpg
#   inflating: train_val_data/9/class-9-266.jpg
#   inflating: train_val_data/9/class-9-267.jpg
#   inflating: train_val_data/9/class-9-268.jpg
#   inflating: train_val_data/9/class-9-269.jpg
#   inflating: train_val_data/9/class-9-27.jpg
#   inflating: train_val_data/9/class-9-271.jpg
#   inflating: train_val_data/9/class-9-272.jpg
#   inflating: train_val_data/9/class-9-273.jpg
#   inflating: train_val_data/9/class-9-275.jpg
#   inflating: train_val_data/9/class-9-277.jpg
#   inflating: train_val_data/9/class-9-278.jpg
#   inflating: train_val_data/9/class-9-279.jpg
#   inflating: train_val_data/9/class-9-28.jpg
#   inflating: train_val_data/9/class-9-280.jpg
#   inflating: train_val_data/9/class-9-281.jpg
#   inflating: train_val_data/9/class-9-282.jpg
#   inflating: train_val_data/9/class-9-283.jpg
#   inflating: train_val_data/9/class-9-284.jpg
#   inflating: train_val_data/9/class-9-285.jpg
#   inflating: train_val_data/9/class-9-286.jpg
#   inflating: train_val_data/9/class-9-287.jpg
#   inflating: train_val_data/9/class-9-288.jpg
#   inflating: train_val_data/9/class-9-289.jpg
#   inflating: train_val_data/9/class-9-290.jpg
#   inflating: train_val_data/9/class-9-292.jpg
#   inflating: train_val_data/9/class-9-293.jpg
#   inflating: train_val_data/9/class-9-3.jpg
#   inflating: train_val_data/9/class-9-30.jpg
#   inflating: train_val_data/9/class-9-31.jpg
#   inflating: train_val_data/9/class-9-33.jpg
#   inflating: train_val_data/9/class-9-34.jpg
#   inflating: train_val_data/9/class-9-35.jpg
#   inflating: train_val_data/9/class-9-36.jpg
#   inflating: train_val_data/9/class-9-37.jpg
#   inflating: train_val_data/9/class-9-38.jpg
#   inflating: train_val_data/9/class-9-39.jpg
#   inflating: train_val_data/9/class-9-4.jpg
#   inflating: train_val_data/9/class-9-40.jpg
#   inflating: train_val_data/9/class-9-41.jpg
#   inflating: train_val_data/9/class-9-43.jpg
#   inflating: train_val_data/9/class-9-44.jpg
#   inflating: train_val_data/9/class-9-45.jpg
#   inflating: train_val_data/9/class-9-46.jpg
#   inflating: train_val_data/9/class-9-47.jpg
#   inflating: train_val_data/9/class-9-48.jpg
#   inflating: train_val_data/9/class-9-49.jpg
#   inflating: train_val_data/9/class-9-5.jpg
#   inflating: train_val_data/9/class-9-50.jpg
#   inflating: train_val_data/9/class-9-51.jpg
#   inflating: train_val_data/9/class-9-52.jpg
#   inflating: train_val_data/9/class-9-53.jpg
#   inflating: train_val_data/9/class-9-54.jpg
#   inflating: train_val_data/9/class-9-55.jpg
#   inflating: train_val_data/9/class-9-6.jpg
#   inflating: train_val_data/9/class-9-60.jpg
#   inflating: train_val_data/9/class-9-62.jpg
#   inflating: train_val_data/9/class-9-63.jpg
#   inflating: train_val_data/9/class-9-64.jpg
#   inflating: train_val_data/9/class-9-65.jpg
#   inflating: train_val_data/9/class-9-67.jpg
#   inflating: train_val_data/9/class-9-68.jpg
#   inflating: train_val_data/9/class-9-69.jpg
#   inflating: train_val_data/9/class-9-7.jpg
#   inflating: train_val_data/9/class-9-70.jpg
#   inflating: train_val_data/9/class-9-71.jpg
#   inflating: train_val_data/9/class-9-72.jpg
#   inflating: train_val_data/9/class-9-73.jpg
#   inflating: train_val_data/9/class-9-74.jpg
#   inflating: train_val_data/9/class-9-75.jpg
#   inflating: train_val_data/9/class-9-76.jpg
#   inflating: train_val_data/9/class-9-77.jpg
#   inflating: train_val_data/9/class-9-78.jpg
#   inflating: train_val_data/9/class-9-79.jpg
#   inflating: train_val_data/9/class-9-8.jpg
#   inflating: train_val_data/9/class-9-80.jpg
#   inflating: train_val_data/9/class-9-81.jpg
#   inflating: train_val_data/9/class-9-82.jpg
#   inflating: train_val_data/9/class-9-83.jpg
#   inflating: train_val_data/9/class-9-84.jpg
#   inflating: train_val_data/9/class-9-86.jpg
#   inflating: train_val_data/9/class-9-87.jpg
#   inflating: train_val_data/9/class-9-88.jpg
#   inflating: train_val_data/9/class-9-9.jpg
#   inflating: train_val_data/9/class-9-91.jpg
#   inflating: train_val_data/9/class-9-92.jpg
#   inflating: train_val_data/9/class-9-93.jpg
#   inflating: train_val_data/9/class-9-94.jpg
#   inflating: train_val_data/9/class-9-95.jpg
#   inflating: train_val_data/9/class-9-96.jpg
#   inflating: train_val_data/9/class-9-97.jpg
#   inflating: train_val_data/9/class-9-98.jpg
#   inflating: train_val_data/9/class-9-99.jpg

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define the directory paths
data_dir = '/content/train_val_data'
img_size = (224, 224)
batch_size = 32

# Create ImageDataGenerator instances for train, validation, and test sets with augmentation for training set
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2  # Split the data into 80% train and 20% validation
)

validation_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

validation_generator = validation_datagen.flow_from_directory(
    data_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=True
)
# Out:
# Found 8546 images belonging to 38 classes.
# Found 2115 images belonging to 38 classes.

# %%
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout

# Load the ResNet50 model pre-trained on ImageNet
base_model = DenseNet201(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Add custom layers on top of the base model
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)  # Add dropout for regularization
predictions = Dense(38, activation='softmax')(x)

# Define the model
model = Model(inputs=base_model.input, outputs=predictions)

# Make all layers trainable for fine-tuning
for layer in base_model.layers:
    layer.trainable = True

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(1e-5), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# Define callbacks
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_accuracy', save_best_only=True, mode='max')
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-7)

# Train the model
history = model.fit(
    train_generator,
    epochs=100 ,
    validation_data=validation_generator,
    callbacks=[checkpoint, early_stopping, reduce_lr]
)
# Out:
# Epoch 1/100
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 906s 2s/step - accuracy: 0.0422 - loss: 3.8054 - val_accuracy: 0.2260 - val_loss: 3.0938 - learning_rate: 1.0000e-05
# Epoch 2/100
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 181s 664ms/step - accuracy: 0.2349 - loss: 2.9125 - val_accuracy: 0.5934 - val_loss: 1.9089 - learning_rate: 1.0000e-05
# Epoch 3/100
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 193s 631ms/step - accuracy: 0.5491 - loss: 1.8073 - val_accuracy: 0.7475 - val_loss: 1.0886 - learning_rate: 1.0000e-05
# Epoch 4/100
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 202s 631ms/step - accuracy: 0.7346 - loss: 1.0617 - val_accuracy: 0.8123 - val_loss: 0.7454 - learning_rate: 1.0000e-05
# Epoch 5/100
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 194s 606ms/step - accuracy: 0.8007 - loss: 0.7357 - val_accuracy: 0.8407 - val_loss: 0.5708 - learning_rate: 1.0000e-05
# Epoch 6/100
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 173s 635ms/step - accuracy: 0.8611 - loss: 0.5357 - val_accuracy: 0.8553 - val_loss: 0.4777 - learning_rate: 1.0000e-05
# Epoch 7/100
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 196s 615ms/step - accuracy: 0.9029 - loss: 0.3926 - val_accuracy: 0.8733 - val_loss: 0.4250 - learning_rate: 1.0000e-05
# Epoch 8/100
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 198s 600ms/step - accuracy: 0.9125 - loss: 0.3409 - val_accuracy: 0.8709 - val_loss: 0.4130 - learning_rate: 1.0000e-05
# Epoch 9/100
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 170s 620ms/step - accuracy: 0.9321 - loss: 0.2601 - val_accuracy: 0.8775 - val_loss: 0.4003 - learning_rate: 1.0000e-05
# Epoch 10/100
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 166s 610ms/step - accuracy: 0.9400 - loss: 0.2225 - val_accuracy: 0.8856 - val_loss: 0.3709 - learning_rate: 1.0000e-05
# Epoch 11/100
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 203s 606ms/step - accuracy: 0.9521 - loss: 0.1851 - val_accuracy: 0.8861 - val_loss: 0.3547 - learning_rate: 1.0000e-05
# Epoch 12/100
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 208s 633ms/step - accuracy: 0.9592 - loss: 0.1640 - val_accuracy: 0.8889 - val_loss: 0.3578 - learning_rate: 1.0000e-05
# Epoch 13/100
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 194s 603ms/step - accuracy: 0.9628 - loss: 0.1451 - val_accuracy: 0.8894 - val_loss: 0.3600 - learning_rate: 1.0000e-05
# Epoch 14/100
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 168s 611ms/step - accuracy: 0.9643 - loss: 0.1339 - val_accuracy: 0.9012 - val_loss: 0.3413 - learning_rate: 1.0000e-05
# Epoch 15/100
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 199s 607ms/step - accuracy: 0.9717 - loss: 0.1080 - val_accuracy: 0.9026 - val_loss: 0.3373 - learning_rate: 1.0000e-05
# Epoch 16/100
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 206s 622ms/step - accuracy: 0.9708 - loss: 0.1038 - val_accuracy: 0.9045 - val_loss: 0.3261 - learning_rate: 1.0000e-05
# Epoch 17/100
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 192s 586ms/step - accuracy: 0.9787 - loss: 0.0873 - val_accuracy: 0.8974 - val_loss: 0.3569 - learning_rate: 1.0000e-05
# Epoch 18/100
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 205s 595ms/step - accuracy: 0.9763 - loss: 0.0871 - val_accuracy: 0.9031 - val_loss: 0.3273 - learning_rate: 1.0000e-05
# Epoch 19/100
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 160s 588ms/step - accuracy: 0.9823 - loss: 0.0727 - val_accuracy: 0.8955 - val_loss: 0.3526 - learning_rate: 1.0000e-05
# Epoch 20/100
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 204s 596ms/step - accuracy: 0.9867 - loss: 0.0595 - val_accuracy: 0.9031 - val_loss: 0.3314 - learning_rate: 2.0000e-06
# Epoch 21/100
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 163s 598ms/step - accuracy: 0.9884 - loss: 0.0534 - val_accuracy: 0.9059 - val_loss: 0.3323 - learning_rate: 2.0000e-06

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve, auc, accuracy_score

# Recheck Data Generators
test_generator = test_datagen.flow_from_directory(
    '/content/test_data',  # Make sure this directory is correct
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False  # Ensure no shuffling for consistency in predictions
)

# 1. Evaluate model on the test set
test_loss, test_acc = model.evaluate(test_generator)
print(f'Test accuracy from evaluate: {test_acc * 100:.2f}%')


# Evaluate the model on test set
predictions = model.predict(test_generator)
y_true = test_generator.classes
y_pred = np.argmax(predictions, axis=1)

# Calculate accuracy score
accuracy = accuracy_score(y_true, y_pred)
print("Accuracy:", accuracy)

# Generate confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)

# Plot confusion matrix using Seaborn
plt.figure(figsize=(15, 15))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# Classification report
print("Classification Report:")
print(classification_report(y_true, y_pred))

# Calculate overall ROC AUC score
roc_auc = roc_auc_score(tf.keras.utils.to_categorical(y_true), predictions, average='macro')
print("Overall ROC AUC Score:", roc_auc)

# Plot ROC curve
fpr, tpr, _ = roc_curve(tf.keras.utils.to_categorical(y_true).ravel(), predictions.ravel())
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.5f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve EfficientNet')
plt.legend(loc="lower right")
plt.show()

# Plot loss and accuracy per epoch
plt.figure(figsize=(12, 6))

# Plot training loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot training accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='red')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Found 10661 images belonging to 38 classes.
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 63s 188ms/step - accuracy: 0.9774 - loss: 0.0862
# Test accuracy from evaluate: 97.71%
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 47s 140ms/step
# Accuracy: 0.9771128411968858
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97       288
#            1       0.99      0.99      0.99       284
#            2       1.00      0.97      0.98       301
#            3       0.98      1.00      0.99       253
#            4       0.98      0.97      0.98       270
#            5       0.98      0.97      0.97       284
#            6       0.99      0.97      0.98       297
#            7       0.96      0.95      0.95       310
#            8       0.97      1.00      0.99       252
#            9       0.98      1.00      0.99       274
#           10       0.96      0.96      0.96       278
#           11       0.99      0.94      0.96       292
#           12       0.97      0.98      0.97       263
#           13       0.99      1.00      0.99       288
#           14       1.00      0.99      0.99       288
#           15       1.00      0.96      0.98       299
#           16       0.96      0.96      0.96       279
#           17       0.95      0.99      0.97       296
#           18       0.99      0.98      0.98       293
#           19       0.98      0.99      0.99       285
#           20       1.00      0.98      0.99       275
#           21       0.99      0.99      0.99       281
#           22       0.99      1.00      0.99       271
#           23       0.93      0.99      0.96       271
#           24       0.98      0.99      0.99       291
#           25       0.98      0.98      0.98       279
#           26       0.97      0.93      0.95       255
#           27       0.93      0.97      0.95       302
#           28       0.99      0.99      0.99       279
#           29       0.98      0.95      0.97       312
#           30       0.98      1.00      0.99       269
#           31       1.00      0.99      0.99       278
#           32       0.98      0.98      0.98       265
#           33       0.98      0.96      0.97       267
#           34       0.99      0.96      0.98       283
#           35       0.95      0.99      0.97       277
#           36       0.95      0.99      0.97       269
#           37       0.98      0.96      0.97       263
#
#     accuracy                           0.98     10661
#    macro avg       0.98      0.98      0.98     10661
# weighted avg       0.98      0.98      0.98     10661
#
# Overall ROC AUC Score: 0.9998047884056745

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve

# Function to plot binary classification graphs
def plot_binary_classification_graphs(y_true, y_pred):
    # ROC Curve
    fpr, tpr, thresholds = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)

    plt.figure()
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.show()

    # Precision-Recall Curve
    precision, recall, thresholds = precision_recall_curve(y_true, y_pred)
    plt.figure()
    plt.plot(recall, precision, color='blue', lw=2)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curve')
    plt.show()

# Assuming 'y_test' is your true labels and 'y_pred' are the predicted labels (probabilities)
plot_binary_classification_graphs(y_test, y_pred)
