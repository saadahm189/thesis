# %% [markdown]
# ># Test

# %%
import os
from PIL import Image, ExifTags
from tqdm import tqdm

# Function to resize images in a folder, rename them, and save them to another folder
def resize_and_rename_images(source_folder, destination_folder, target_size=(224, 224)):
    # Create the destination folder if it doesn't exist
    os.makedirs(destination_folder, exist_ok=True)

    # Iterate through subfolders in the source folder
    for subfolder_name in os.listdir(source_folder):
        subfolder_path = os.path.join(source_folder, subfolder_name)
        
        # Create a subdirectory in the destination folder
        output_subfolder = os.path.join(destination_folder, subfolder_name)
        os.makedirs(output_subfolder, exist_ok=True)

        # Initialize counter for renaming images
        image_count = 1

        # Initialize tqdm progress bar
        progress_bar = tqdm(os.listdir(subfolder_path), desc=f'Resizing images in class {subfolder_name}')

        # Iterate through images in the subfolder
        for filename in progress_bar:
            file_path = os.path.join(subfolder_path, filename)
            
            # Open the image and check orientation
            with Image.open(file_path) as img:
                # Check if the image has orientation metadata
                if hasattr(img, '_getexif'):
                    exif = img._getexif()
                    if exif is not None:
                        # Get the orientation tag
                        orientation = exif.get(0x0112)
                        
                        # Rotate the image if necessary
                        if orientation == 3:
                            img = img.rotate(180, expand=True)
                        elif orientation == 6:
                            img = img.rotate(270, expand=True)
                        elif orientation == 8:
                            img = img.rotate(90, expand=True)

                # Resize the image
                img_resized = img.resize(target_size, Image.LANCZOS)

                # Rename the image
                new_filename = f"class-{subfolder_name}-{image_count}.jpg"
                image_count = image_count +1

                # Save the resized and renamed image to the destination folder
                output_file_path = os.path.join(output_subfolder, new_filename)
                img_resized.save(output_file_path)

                # Update tqdm progress bar
                progress_bar.set_postfix({'File': new_filename})

# Path to the source folder containing subfolders with images
source_folder_path = "F:/datasets/dataset"

# Path to the destination folder where resized and renamed images will be saved
destination_folder_path = "F:/thesis/data"

# Resize and rename images and save them to the destination folder
resize_and_rename_images(source_folder_path, destination_folder_path)
# Out:
# Resizing images in class 0: 100%|██████████| 251/251 [00:36<00:00,  6.85it/s, File=class-0-251.jpg]
# Resizing images in class 1: 100%|██████████| 244/244 [00:31<00:00,  7.81it/s, File=class-1-244.jpg]
# Resizing images in class 10: 100%|██████████| 273/273 [00:26<00:00, 10.31it/s, File=class-10-273.jpg]
# Resizing images in class 11: 100%|██████████| 219/219 [00:24<00:00,  9.03it/s, File=class-11-219.jpg]
# Resizing images in class 12: 100%|██████████| 238/238 [00:26<00:00,  8.89it/s, File=class-12-238.jpg]
# Resizing images in class 13: 100%|██████████| 248/248 [00:26<00:00,  9.22it/s, File=class-13-248.jpg]
# Resizing images in class 14: 100%|██████████| 264/264 [00:51<00:00,  5.08it/s, File=class-14-264.jpg]
# Resizing images in class 15: 100%|██████████| 281/281 [01:01<00:00,  4.56it/s, File=class-15-281.jpg]
# Resizing images in class 16: 100%|██████████| 234/234 [00:53<00:00,  4.40it/s, File=class-16-234.jpg]
# Resizing images in class 17: 100%|██████████| 242/242 [00:56<00:00,  4.25it/s, File=class-17-242.jpg]
# Resizing images in class 18: 100%|██████████| 246/246 [01:02<00:00,  3.92it/s, File=class-18-246.jpg]
# Resizing images in class 19: 100%|██████████| 257/257 [01:04<00:00,  3.96it/s, File=class-19-257.jpg]
# Resizing images in class 2: 100%|██████████| 223/223 [01:04<00:00,  3.47it/s, File=class-2-223.jpg]
# Resizing images in class 20: 100%|██████████| 256/256 [01:03<00:00,  4.04it/s, File=class-20-256.jpg]
# Resizing images in class 21: 100%|██████████| 257/257 [00:51<00:00,  5.00it/s, File=class-21-257.jpg]
# Resizing images in class 22: 100%|██████████| 269/269 [01:27<00:00,  3.08it/s, File=class-22-269.jpg]
# Resizing images in class 23: 100%|██████████| 249/249 [01:14<00:00,  3.35it/s, File=class-23-249.jpg]
# Resizing images in class 24: 100%|██████████| 264/264 [01:19<00:00,  3.34it/s, File=class-24-264.jpg]
# Resizing images in class 25: 100%|██████████| 262/262 [01:11<00:00,  3.64it/s, File=class-25-262.jpg]
# Resizing images in class 26: 100%|██████████| 250/250 [01:06<00:00,  3.77it/s, File=class-26-250.jpg]
# Resizing images in class 27: 100%|██████████| 243/243 [00:59<00:00,  4.10it/s, File=class-27-243.jpg]
# Resizing images in class 28: 100%|██████████| 250/250 [00:48<00:00,  5.21it/s, File=class-28-250.jpg]
# Resizing images in class 29: 100%|██████████| 240/240 [01:01<00:00,  3.89it/s, File=class-29-240.jpg]
# Resizing images in class 3: 100%|██████████| 233/233 [01:11<00:00,  3.24it/s, File=class-3-233.jpg]
# Resizing images in class 30: 100%|██████████| 249/249 [01:05<00:00,  3.79it/s, File=class-30-249.jpg]
# Resizing images in class 31: 100%|██████████| 243/243 [01:04<00:00,  3.74it/s, File=class-31-243.jpg]
# Resizing images in class 32: 100%|██████████| 221/221 [00:46<00:00,  4.73it/s, File=class-32-221.jpg]
# Resizing images in class 33: 100%|██████████| 271/271 [00:58<00:00,  4.61it/s, File=class-33-271.jpg]
# Resizing images in class 34: 100%|██████████| 257/257 [01:09<00:00,  3.68it/s, File=class-34-257.jpg]
# Resizing images in class 35: 100%|██████████| 284/284 [00:57<00:00,  4.96it/s, File=class-35-284.jpg]
# Resizing images in class 36: 100%|██████████| 259/259 [00:28<00:00,  8.98it/s, File=class-36-259.jpg]
# Resizing images in class 37: 100%|██████████| 244/244 [00:29<00:00,  8.41it/s, File=class-37-244.jpg]
# Resizing images in class 4: 100%|██████████| 225/225 [00:27<00:00,  8.23it/s, File=class-4-225.jpg]
# Resizing images in class 5: 100%|██████████| 225/225 [00:57<00:00,  3.89it/s, File=class-5-225.jpg]
# Resizing images in class 6: 100%|██████████| 252/252 [01:07<00:00,  3.75it/s, File=class-6-252.jpg]
# Resizing images in class 7: 100%|██████████| 237/237 [01:04<00:00,  3.68it/s, File=class-7-237.jpg]
# Resizing images in class 8: 100%|██████████| 235/235 [01:01<00:00,  3.82it/s, File=class-8-235.jpg]
# Resizing images in class 9: 100%|██████████| 230/230 [01:03<00:00,  3.62it/s, File=class-9-230.jpg]
