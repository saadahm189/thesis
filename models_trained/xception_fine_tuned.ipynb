# %% [markdown]
# # Model: Xception
# Fine Tuned

# %% [markdown]
# ## Warning ignored

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Import Libraries

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import seaborn as sns
import os
import cv2
from tqdm import tqdm
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D, Flatten, Conv2D, BatchNormalization, Activation, MaxPooling2D
from keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.optimizers import RMSprop, SGD, Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score, roc_curve, auc
import seaborn as sns

# %% [markdown]
# ## For Colab uncomment

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# !unzip "/content/drive/MyDrive/Dataset/data.zip"

# %% [markdown]
# ## Edit Paths

# %%
location = '/content/data'
no_of_classes = 38
batch_size = 32
size = 224

# %% [markdown]
# ## Data loading

# %%
gpus = tf.config.list_logical_devices('GPU')
stg=tf.distribute.MirroredStrategy(gpus)

folder_dir = location
total_files = sum(len(files) for _, _, files in os.walk(folder_dir))

with tqdm(total=total_files, desc="Processing Images") as pbar:
    for folder in os.listdir(folder_dir):
        for file in os.listdir(os.path.join(folder_dir, folder)):
            image_path = os.path.join(folder_dir, folder, file)
            img = cv2.imread(image_path)
            img_resized = cv2.resize(img, (size, size))
            cv2.imwrite(image_path, img_resized)
            pbar.update(1)
picture_size = (size, size)
train_set = tf.keras.utils.image_dataset_from_directory(
    directory=folder_dir,
    shuffle=True,
    image_size=picture_size,
    batch_size=batch_size,
    label_mode='categorical',
    validation_split=0.2,
    subset='training',
    seed=22
)

validation_set = tf.keras.utils.image_dataset_from_directory(
    directory=folder_dir,
    shuffle=True,
    image_size=picture_size,
    batch_size=batch_size,
    label_mode='categorical',
    validation_split=0.2,
    subset='validation',
    seed=22
)
# Out:
# Processing Images: 100%|██████████| 11864/11864 [00:22<00:00, 535.26it/s]
# Found 11864 files belonging to 38 classes.
# Using 9492 files for training.
# Found 11864 files belonging to 38 classes.
# Using 2372 files for validation.

# %% [markdown]
# ## Model building

# %%
with stg.scope():
    # Data Augmentation
    img_augmentation = tf.keras.Sequential([
        tf.keras.layers.experimental.preprocessing.RandomRotation(factor=0.2),
        tf.keras.layers.experimental.preprocessing.RandomTranslation(
            height_factor=0.1, width_factor=0.1),
        tf.keras.layers.experimental.preprocessing.RandomZoom(
            height_factor=0.2),
        tf.keras.layers.experimental.preprocessing.RandomFlip(
            mode='horizontal'),
        tf.keras.layers.experimental.preprocessing.RandomContrast(factor=0.2)
    ], name="img_augmentation")

    base_model = Xception(weights="imagenet", input_shape=(
        size, size, 3), include_top=False)
    inputs = Input(shape=(size, size, 3))
    x = img_augmentation(inputs)
    outputs = base_model(x)

    x = GlobalAveragePooling2D()(outputs)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(32, activation='relu')(x)
    outputs = Dense(no_of_classes, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=outputs)

    model.compile(
        loss='categorical_crossentropy',
        optimizer=Adam(learning_rate=0.001),
        metrics=['accuracy'])

lr_scheduler = ReduceLROnPlateau(monitor='val_loss',
                                 factor=0.1,
                                 patience=2,
                                 verbose=1)
early_stopping = EarlyStopping(monitor='val_loss',
                               patience=5,
                               verbose=1)

callbacks = [lr_scheduler, early_stopping]

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  img_augmentation (Sequenti  (None, 224, 224, 3)       0
#  al)
#
#  xception (Functional)       (None, 7, 7, 2048)        20861480
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               1049088
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 32)                16416
#
#  dense_2 (Dense)             (None, 38)                1254
#
# =================================================================
# Total params: 21928238 (83.65 MB)
# Trainable params: 21873710 (83.44 MB)
# Non-trainable params: 54528 (213.00 KB)
# _________________________________________________________________

# %% [markdown]
# ## Model Train

# %%
history = model.fit(train_set, epochs=100, validation_data=validation_set, callbacks=callbacks,
                    steps_per_epoch=len(train_set), validation_steps=len(validation_set))
# Out:
# Epoch 1/100
# 297/297 [==============================] - 221s 606ms/step - loss: 3.6385 - accuracy: 0.0245 - val_loss: 3.6381 - val_accuracy: 0.0257 - lr: 0.0010
# Epoch 2/100
# 297/297 [==============================] - 165s 554ms/step - loss: 3.6377 - accuracy: 0.0264 - val_loss: 6248.8237 - val_accuracy: 0.0228 - lr: 0.0010
# Epoch 3/100
# 297/297 [==============================] - ETA: 0s - loss: 3.5473 - accuracy: 0.0396
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 297/297 [==============================] - 161s 543ms/step - loss: 3.5473 - accuracy: 0.0396 - val_loss: 3.8848 - val_accuracy: 0.0396 - lr: 0.0010
# Epoch 4/100
# 297/297 [==============================] - 161s 543ms/step - loss: 3.2342 - accuracy: 0.0587 - val_loss: 3.1968 - val_accuracy: 0.0569 - lr: 1.0000e-04
# Epoch 5/100
# 297/297 [==============================] - 161s 543ms/step - loss: 3.1536 - accuracy: 0.0671 - val_loss: 3.1031 - val_accuracy: 0.0675 - lr: 1.0000e-04
# Epoch 6/100
# 297/297 [==============================] - 162s 546ms/step - loss: 3.0956 - accuracy: 0.0741 - val_loss: 3.0769 - val_accuracy: 0.0721 - lr: 1.0000e-04
# Epoch 7/100
# 297/297 [==============================] - 162s 545ms/step - loss: 3.0337 - accuracy: 0.0796 - val_loss: 2.9694 - val_accuracy: 0.0734 - lr: 1.0000e-04
# Epoch 8/100
# 297/297 [==============================] - 162s 545ms/step - loss: 2.9514 - accuracy: 0.0864 - val_loss: 2.8943 - val_accuracy: 0.0877 - lr: 1.0000e-04
# Epoch 9/100
# 297/297 [==============================] - 162s 545ms/step - loss: 2.8840 - accuracy: 0.0942 - val_loss: 2.7906 - val_accuracy: 0.0906 - lr: 1.0000e-04
# Epoch 10/100
# 297/297 [==============================] - 162s 546ms/step - loss: 2.8046 - accuracy: 0.1061 - val_loss: 2.7722 - val_accuracy: 0.1223 - lr: 1.0000e-04
# Epoch 11/100
# 297/297 [==============================] - 172s 580ms/step - loss: 2.6959 - accuracy: 0.1369 - val_loss: 2.5669 - val_accuracy: 0.2015 - lr: 1.0000e-04
# Epoch 12/100
# 297/297 [==============================] - 164s 551ms/step - loss: 2.3998 - accuracy: 0.2230 - val_loss: 2.2739 - val_accuracy: 0.2812 - lr: 1.0000e-04
# Epoch 13/100
# 297/297 [==============================] - 164s 551ms/step - loss: 1.9875 - accuracy: 0.3465 - val_loss: 1.8875 - val_accuracy: 0.3954 - lr: 1.0000e-04
# Epoch 14/100
# 297/297 [==============================] - 164s 551ms/step - loss: 1.6027 - accuracy: 0.4638 - val_loss: 1.5037 - val_accuracy: 0.5030 - lr: 1.0000e-04
# Epoch 15/100
# 297/297 [==============================] - 164s 552ms/step - loss: 1.2751 - accuracy: 0.5843 - val_loss: 1.0946 - val_accuracy: 0.6467 - lr: 1.0000e-04
# Epoch 16/100
# 297/297 [==============================] - 174s 587ms/step - loss: 1.0614 - accuracy: 0.6529 - val_loss: 0.9022 - val_accuracy: 0.7146 - lr: 1.0000e-04
# Epoch 17/100
# 297/297 [==============================] - 164s 554ms/step - loss: 0.8699 - accuracy: 0.7205 - val_loss: 0.8766 - val_accuracy: 0.7298 - lr: 1.0000e-04
# Epoch 18/100
# 297/297 [==============================] - 175s 587ms/step - loss: 0.7692 - accuracy: 0.7577 - val_loss: 0.8331 - val_accuracy: 0.7340 - lr: 1.0000e-04
# Epoch 19/100
# 297/297 [==============================] - 165s 555ms/step - loss: 0.6827 - accuracy: 0.7834 - val_loss: 0.6506 - val_accuracy: 0.7804 - lr: 1.0000e-04
# Epoch 20/100
# 297/297 [==============================] - 175s 588ms/step - loss: 0.6163 - accuracy: 0.8102 - val_loss: 0.5650 - val_accuracy: 0.8242 - lr: 1.0000e-04
# Epoch 21/100
# 297/297 [==============================] - 165s 554ms/step - loss: 0.5609 - accuracy: 0.8217 - val_loss: 0.6403 - val_accuracy: 0.8086 - lr: 1.0000e-04
# Epoch 22/100
# 297/297 [==============================] - ETA: 0s - loss: 0.4841 - accuracy: 0.8448
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 297/297 [==============================] - 164s 553ms/step - loss: 0.4841 - accuracy: 0.8448 - val_loss: 0.5750 - val_accuracy: 0.8347 - lr: 1.0000e-04
# Epoch 23/100
# 297/297 [==============================] - 164s 553ms/step - loss: 0.4154 - accuracy: 0.8668 - val_loss: 0.3490 - val_accuracy: 0.8971 - lr: 1.0000e-05
# Epoch 24/100
# 297/297 [==============================] - 165s 555ms/step - loss: 0.3787 - accuracy: 0.8816 - val_loss: 0.3354 - val_accuracy: 0.8988 - lr: 1.0000e-05
# Epoch 25/100
# 297/297 [==============================] - 165s 555ms/step - loss: 0.3642 - accuracy: 0.8891 - val_loss: 0.3200 - val_accuracy: 0.9060 - lr: 1.0000e-05
# Epoch 26/100
# 297/297 [==============================] - 165s 554ms/step - loss: 0.3494 - accuracy: 0.8931 - val_loss: 0.3242 - val_accuracy: 0.9056 - lr: 1.0000e-05
# Epoch 27/100
# 297/297 [==============================] - 164s 553ms/step - loss: 0.3478 - accuracy: 0.8894 - val_loss: 0.3180 - val_accuracy: 0.9056 - lr: 1.0000e-05
# Epoch 28/100
# 297/297 [==============================] - 175s 589ms/step - loss: 0.3347 - accuracy: 0.8976 - val_loss: 0.3191 - val_accuracy: 0.9043 - lr: 1.0000e-05
# Epoch 29/100
# 297/297 [==============================] - 165s 556ms/step - loss: 0.3302 - accuracy: 0.8973 - val_loss: 0.3073 - val_accuracy: 0.9153 - lr: 1.0000e-05
# Epoch 30/100
# 297/297 [==============================] - 165s 554ms/step - loss: 0.3180 - accuracy: 0.9044 - val_loss: 0.3105 - val_accuracy: 0.9064 - lr: 1.0000e-05
# Epoch 31/100
# 297/297 [==============================] - 164s 553ms/step - loss: 0.3170 - accuracy: 0.9020 - val_loss: 0.3003 - val_accuracy: 0.9123 - lr: 1.0000e-05
# Epoch 32/100
# 297/297 [==============================] - 165s 555ms/step - loss: 0.3004 - accuracy: 0.9060 - val_loss: 0.3002 - val_accuracy: 0.9106 - lr: 1.0000e-05
# Epoch 33/100
# 297/297 [==============================] - 165s 555ms/step - loss: 0.2898 - accuracy: 0.9101 - val_loss: 0.2924 - val_accuracy: 0.9077 - lr: 1.0000e-05
# Epoch 34/100
# 297/297 [==============================] - 165s 554ms/step - loss: 0.2964 - accuracy: 0.9054 - val_loss: 0.2928 - val_accuracy: 0.9136 - lr: 1.0000e-05
# Epoch 35/100
# 297/297 [==============================] - 174s 587ms/step - loss: 0.2836 - accuracy: 0.9130 - val_loss: 0.2856 - val_accuracy: 0.9191 - lr: 1.0000e-05
# Epoch 36/100
# 297/297 [==============================] - 165s 555ms/step - loss: 0.2787 - accuracy: 0.9136 - val_loss: 0.2844 - val_accuracy: 0.9169 - lr: 1.0000e-05
# Epoch 37/100
# 297/297 [==============================] - 165s 553ms/step - loss: 0.2770 - accuracy: 0.9148 - val_loss: 0.2829 - val_accuracy: 0.9165 - lr: 1.0000e-05
# Epoch 38/100
# 297/297 [==============================] - 165s 555ms/step - loss: 0.2828 - accuracy: 0.9139 - val_loss: 0.2820 - val_accuracy: 0.9228 - lr: 1.0000e-05
# Epoch 39/100
# 297/297 [==============================] - 165s 554ms/step - loss: 0.2656 - accuracy: 0.9184 - val_loss: 0.2710 - val_accuracy: 0.9224 - lr: 1.0000e-05
# Epoch 40/100
# 297/297 [==============================] - 165s 554ms/step - loss: 0.2589 - accuracy: 0.9204 - val_loss: 0.2675 - val_accuracy: 0.9207 - lr: 1.0000e-05
# Epoch 41/100
# 297/297 [==============================] - 165s 556ms/step - loss: 0.2567 - accuracy: 0.9210 - val_loss: 0.2735 - val_accuracy: 0.9186 - lr: 1.0000e-05
# Epoch 42/100
# 297/297 [==============================] - 165s 554ms/step - loss: 0.2580 - accuracy: 0.9177 - val_loss: 0.2562 - val_accuracy: 0.9266 - lr: 1.0000e-05
# Epoch 43/100
# 297/297 [==============================] - 165s 556ms/step - loss: 0.2572 - accuracy: 0.9184 - val_loss: 0.2573 - val_accuracy: 0.9220 - lr: 1.0000e-05
# Epoch 44/100
# 297/297 [==============================] - ETA: 0s - loss: 0.2428 - accuracy: 0.9255
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 297/297 [==============================] - 165s 556ms/step - loss: 0.2428 - accuracy: 0.9255 - val_loss: 0.2592 - val_accuracy: 0.9254 - lr: 1.0000e-05
# Epoch 45/100
# 297/297 [==============================] - 175s 588ms/step - loss: 0.2266 - accuracy: 0.9286 - val_loss: 0.2553 - val_accuracy: 0.9279 - lr: 1.0000e-06
# Epoch 46/100
# 297/297 [==============================] - 175s 588ms/step - loss: 0.2353 - accuracy: 0.9249 - val_loss: 0.2540 - val_accuracy: 0.9266 - lr: 1.0000e-06
# Epoch 47/100
# 297/297 [==============================] - 165s 555ms/step - loss: 0.2233 - accuracy: 0.9324 - val_loss: 0.2519 - val_accuracy: 0.9266 - lr: 1.0000e-06
# Epoch 48/100
# 297/297 [==============================] - 165s 555ms/step - loss: 0.2382 - accuracy: 0.9258 - val_loss: 0.2534 - val_accuracy: 0.9266 - lr: 1.0000e-06
# Epoch 49/100
# 297/297 [==============================] - 165s 554ms/step - loss: 0.2362 - accuracy: 0.9264 - val_loss: 0.2515 - val_accuracy: 0.9266 - lr: 1.0000e-06
# Epoch 50/100
# 297/297 [==============================] - 165s 555ms/step - loss: 0.2268 - accuracy: 0.9283 - val_loss: 0.2510 - val_accuracy: 0.9271 - lr: 1.0000e-06
# Epoch 51/100
# 297/297 [==============================] - 165s 555ms/step - loss: 0.2304 - accuracy: 0.9279 - val_loss: 0.2506 - val_accuracy: 0.9266 - lr: 1.0000e-06
# Epoch 52/100
# 297/297 [==============================] - 165s 554ms/step - loss: 0.2288 - accuracy: 0.9325 - val_loss: 0.2490 - val_accuracy: 0.9283 - lr: 1.0000e-06
# Epoch 53/100
# 297/297 [==============================] - 165s 554ms/step - loss: 0.2283 - accuracy: 0.9298 - val_loss: 0.2509 - val_accuracy: 0.9275 - lr: 1.0000e-06
# Epoch 54/100
# 297/297 [==============================] - ETA: 0s - loss: 0.2311 - accuracy: 0.9272
# Epoch 54: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 297/297 [==============================] - 165s 555ms/step - loss: 0.2311 - accuracy: 0.9272 - val_loss: 0.2524 - val_accuracy: 0.9271 - lr: 1.0000e-06
# Epoch 55/100
# 297/297 [==============================] - 175s 588ms/step - loss: 0.2286 - accuracy: 0.9268 - val_loss: 0.2498 - val_accuracy: 0.9283 - lr: 1.0000e-07
# Epoch 56/100
# 297/297 [==============================] - ETA: 0s - loss: 0.2156 - accuracy: 0.9347
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 297/297 [==============================] - 165s 556ms/step - loss: 0.2156 - accuracy: 0.9347 - val_loss: 0.2506 - val_accuracy: 0.9283 - lr: 1.0000e-07
# Epoch 57/100
# 297/297 [==============================] - 164s 553ms/step - loss: 0.2285 - accuracy: 0.9265 - val_loss: 0.2487 - val_accuracy: 0.9292 - lr: 1.0000e-08
# Epoch 58/100
# 297/297 [==============================] - 165s 554ms/step - loss: 0.2335 - accuracy: 0.9253 - val_loss: 0.2501 - val_accuracy: 0.9288 - lr: 1.0000e-08
# Epoch 59/100
# 297/297 [==============================] - ETA: 0s - loss: 0.2304 - accuracy: 0.9318
# Epoch 59: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# 297/297 [==============================] - 164s 553ms/step - loss: 0.2304 - accuracy: 0.9318 - val_loss: 0.2519 - val_accuracy: 0.9275 - lr: 1.0000e-08
# Epoch 60/100
# 297/297 [==============================] - 165s 556ms/step - loss: 0.2297 - accuracy: 0.9289 - val_loss: 0.2507 - val_accuracy: 0.9292 - lr: 1.0000e-09
# Epoch 61/100
# 297/297 [==============================] - ETA: 0s - loss: 0.2272 - accuracy: 0.9280
# Epoch 61: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-10.
# 297/297 [==============================] - 175s 588ms/step - loss: 0.2272 - accuracy: 0.9280 - val_loss: 0.2507 - val_accuracy: 0.9279 - lr: 1.0000e-09
# Epoch 62/100
# 297/297 [==============================] - 165s 556ms/step - loss: 0.2230 - accuracy: 0.9308 - val_loss: 0.2514 - val_accuracy: 0.9279 - lr: 1.0000e-10
# Epoch 62: early stopping

# %% [markdown]
# ## Evaluation

# %%
test_data_dir = location
test_datagen = ImageDataGenerator()
test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=picture_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
test_loss, test_acc = model.evaluate_generator(test_generator)
print('Test accuracy:', test_acc)
# Out:
# Found 11864 images belonging to 38 classes.
# Test accuracy: 0.9520397782325745

# %%
# Evaluate the model on test set
predictions = model.predict(test_generator)
y_true = test_generator.classes
y_pred = np.argmax(predictions, axis=1)

# Calculate accuracy score
accuracy = accuracy_score(y_true, y_pred)
print("Accuracy:", accuracy)

# Generate confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)

# Plot confusion matrix using Seaborn
plt.figure(figsize=(15, 15))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# Classification report
print("Classification Report:")
print(classification_report(y_true, y_pred))

# Calculate overall ROC AUC score
roc_auc = roc_auc_score(tf.keras.utils.to_categorical(y_true), predictions, average='macro')
print("Overall ROC AUC Score:", roc_auc)

# Plot ROC curve
fpr, tpr, _ = roc_curve(tf.keras.utils.to_categorical(y_true).ravel(), predictions.ravel())
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.5f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Curve EfficientNet')
plt.legend(loc="lower right")
plt.show()
# Out:
# 371/371 [==============================] - 56s 149ms/step
# Accuracy: 0.9520397842211733
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94       320
#            1       0.96      0.98      0.97       316
#            2       0.98      0.99      0.99       335
#            3       0.97      0.96      0.96       282
#            4       0.95      0.83      0.89       301
#            5       0.97      0.94      0.96       316
#            6       0.91      0.97      0.94       330
#            7       0.95      0.90      0.92       345
#            8       0.99      0.97      0.98       280
#            9       0.99      1.00      1.00       305
#           10       0.93      0.95      0.94       309
#           11       0.92      0.86      0.89       325
#           12       0.97      0.95      0.96       293
#           13       0.97      0.99      0.98       320
#           14       1.00      0.98      0.99       321
#           15       0.95      0.95      0.95       333
#           16       0.88      0.91      0.89       311
#           17       0.92      0.98      0.95       329
#           18       0.99      0.98      0.99       326
#           19       0.98      0.98      0.98       317
#           20       0.96      0.98      0.97       306
#           21       0.96      0.97      0.97       313
#           22       0.96      0.94      0.95       302
#           23       0.93      0.84      0.89       302
#           24       0.97      0.98      0.98       324
#           25       0.97      0.96      0.97       311
#           26       0.95      0.89      0.92       284
#           27       0.93      0.93      0.93       336
#           28       0.97      0.98      0.98       310
#           29       0.95      0.97      0.96       347
#           30       0.83      0.98      0.90       299
#           31       1.00      0.96      0.98       309
#           32       0.96      0.96      0.96       295
#           33       0.95      0.93      0.94       297
#           34       0.96      0.97      0.97       315
#           35       0.92      0.94      0.93       308
#           36       0.94      0.96      0.95       299
#           37       0.99      0.98      0.98       293
#
#     accuracy                           0.95     11864
#    macro avg       0.95      0.95      0.95     11864
# weighted avg       0.95      0.95      0.95     11864
#
# Overall ROC AUC Score: 0.9994236042203564

# %%
# plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss vs. Epoch')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.grid()
plt.show()

# %%
# plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy vs. Epoch')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.grid()
plt.show()
